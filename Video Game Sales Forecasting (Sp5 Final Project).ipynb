# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 4:</b><br>
#
#   Hello Jay!,
#
# I am Alexangel, your reviewer in this fourth iteration,
#
# Another project successfully completed - well done! 🏆 Your consistent effort and progress are truly commendable.
#
# Our team is here to help you keep pushing forward and honing your skills as you advance through the program.
#
# You can contact me via Tripleten Hub for further feedback. This information is described below.
#
# **What Was Great**:
# - Excellent job on following the structure of the project.
# - You’ve shown strong skills in building good charts in this project.
#
# **Tips for Future Projects**:
# - Consider adding brief comments after the analysis or graph of every dataframe to make your work even more integral.
#
# Congratulations again on your accomplishment! Each project you complete adds to your growing expertise, and it’s exciting to see you make such great strides. Keep up the great work! 🎯
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer's Tripleten Hub  link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 3:</b><br>
#   Hello Jay!,
#
# I am Alexangel, your current reviewer in this third iteration,
#
#  First of all, congratulations on submitting your project! 🎉
#
#   Taking this step is a big part of your journey into the world of Data, and it’s clear you’re putting in the effort to succeed.
#
#   Our team is here to support your growth, and to help you get the most out of this experience, I’ve returned your project with some suggestions for improvement.
#
# My new comments are marked as `Reviewer's comment 3`, please, read them carefully. You are close to achieve it. You can contact me via Tripleten Hub for further clarification. This information is described below.
#
#  **What Was Great:**
#  - You’ve done a good job with following the general structure of a project.
#  - Your attempt at building good charts shows promise.
#
#  **Areas to Improve:**
#  - To fully meet the project criteria, you'll need to fix the red comments I left below, I also made some comments and recommendations about how to fix them.
#  - Consider adding brief comments after the analysis of every dataset or chart to make your project even more integral.
#
#  Don’t be discouraged - this is all part of the learning process! Take your time to review the feedback and make the necessary adjustments. Resubmit when you’re ready, and I’m confident you’ll nail it on the next go. Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# -------------------------------------------------------------------------------------------------------------
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
# You can find my comments highlighted in green, yellow, or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# You can answer me by using this:
# <div class="alert alert-block alert-info">
# <b>Thanks for your feedback Alexangel! </b> <a class="tocSkip"></a>
# </div>
#
# -------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer’s Tripleten Hub link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer’s comments – Iteration 2:</b><br>
#   Hello Jay!,
#
# I am Alexangel, your current reviewer,
#
#  First of all, congratulations on submitting your project! 🎉
#
#   Taking this step is a big part of your journey into the world of Data, and it’s clear you’re putting in the effort to succeed.
#
#   Our team is here to support your growth, and to help you get the most out of this experience, I’ve returned your project with some suggestions for improvement.
#
# My newYou can contact me via Tripleten Hub for further clarification. This information is described below.
#
#  **What Was Great:**
#  - You’ve done a good job with following the general structure of a project.
#  - Your attempt at building good charts shows promise.
#
#  **Areas to Improve:**
#  - To fully meet the project criteria, you'll need to fix the red comments I left below, I also made some comments and recommendations about how to fix them.
#  - Consider adding brief comments after the analysis of every dataset or chart to make your project even more integral.
#
#  Don’t be discouraged - this is all part of the learning process! Take your time to review the feedback and make the necessary adjustments. Resubmit when you’re ready, and I’m confident you’ll nail it on the next go. Remember, every challenge is an opportunity to grow. You’ve got this! 🏄
#
# -------------------------------------------------------------------------------------------------------------
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
# You can find my comments highlighted in green, yellow, or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# You can answer me by using this:
# <div class="alert alert-block alert-info">
# <b>Thanks for your feedback Alexangel! I've completed the newest round of required edits</b> <a class="tocSkip"></a>
# </div>
#
# -------------------------------------------------------------------------------------------------------------
#
# ***Name of the reviewer***: Alexangel Bracho
#
# ***Reviewer’s Tripleten Hub link*** : [reviewer's link](https://hub.tripleten.com/u/6b1cbe37)

# %% [markdown]
# # Video Game Sales Analysis Project
# ## Project Overview
#
# In this project, you'll analyze video game sales data to identify patterns that determine a game's success. Working as an analyst for the online store Ice, you'll use this information to help plan future advertising campaigns.
#
# ## Environment Setup and Required Libraries

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# You should add an introduction about what the project will be about, its objectives and within others.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Done :)</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# ### Introduction
#
# This project is about identifying patterns that determine whether a game succeeds or not, allowing us to spot potential big winners and plan advertising campaigns.
#
# The objectives will be to first determine what years we want to look at, which range of years is most relevant to our objective. To do this we'll conduct a comprehensive analysis of game sales, their influences and trends and year over year growth within the dataset.
#
# Second, we determine our subset year range, we'll then conduct a comparative analysis of sales, searching for whether/how user and critic scores, ratings, and region correlate with sales.
#
# Finally, we will summarize what we have observed and concluded from the above two steps.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good introduction.
#
# </div>

# %%
# Import all required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import math as mt

# %% [markdown]
# ## Step 1: Loading and Initial Data Exploration
#
# First, let's load our dataset and examine its basic properties:

# %%
# Load the dataset
df_games = pd.read_csv('/datasets/games.csv')

# %%
# Display basic information about the dataset
df_games.info()
print(df_games.columns)
print(df_games.head(5))
print(df_games.tail(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')
# ...

# %%
# Check for duplicate entries
print('Number of duplicates:', df_games.duplicated().sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# ### General Observations & Key Questions Answered
# 16715 total non-null entries/rows
# datatypes preset: float64 & object (may have to convert some)
# ### # of Missing values in:
#     name: 2
#     year_of_release: 269
#     genre: 2
#     critic_score: 8688
#     user_score: 6701
#     rating: 6766
#
# Issues
# ~ critic_score values are float64 but user_score and rating's are object
# ~ other than upper case in every column name, formatting is good
# ~ need to change year_of_release values from float to int
# ~ rating values are in letter format, need to look into that, maybe convert to what they stand for for clarity
#     * E (Everyone), E10+ (Everyone 10+), T (Teen), M (Mature 17+), AO (Adults Only 18+), RP (Rating Pending), K-A (Kids  to Adults), EC (Early Childhood)
#
# Patterns/Anomalies
# ~ some games have sales in all countries, some in 2/3, some in 1/3, some in no countries
# ~ some games have no critic_score and/or user_score and/or rating
# ~ earliest release year is 1980. pre-2000, perhaps even later like 2006 (10 years prior), release years won't be relevant to 2017 projections.

# %%
print('ESRB Rating System:', df_games['Rating'].unique())
print()
print('Earliest Year of Release:', df_games['Year_of_Release'].min().astype(int))
print()

pre_2006_year_of_release = len(df_games[df_games['Year_of_Release'] <= 2006])
post_2006_year_of_release = len(df_games[df_games['Year_of_Release'] >= 2006])
print('# of games released BEFORE 2006 (more than 10 years ago):', pre_2006_year_of_release)
print('# of games released AFTER 2006 (within "last 10 years"):', post_2006_year_of_release)
# Out:
# ESRB Rating System: ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']
#
# Earliest Year of Release: 1980
#
# # of games released BEFORE 2006 (more than 10 years ago): 7119
# # of games released AFTER 2006 (within "last 10 years"): 10333

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good preview of the data.
#
# </div>

# %% [markdown]
# ## Step 2: Data Preparation
#
# ### 2.1 Standardizing Column Names

# %%
# Convert column names to lowercase
df_games.columns = df_games.columns.astype(str).str.lower()

# %%
# Verify the changes
print(df_games.columns)
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### 2.2 Data Type Conversion

# %%
# Check current data types
print(df_games.dtypes)
# Out:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object

# %% [markdown]
# We know the following 4 columns have missing values (nan):
#     year_of_release: 269
#     genre: 2
#     critic_score: 8688
#     user_score: 6701
#     rating: 6766

# %%
# Make changes to data types if necessary
## ~ critic_score values are float64 but user_score is object
## ~ other than upper case in every column name, formatting is good
## ~ rating values are in letter format, need to look into that, maybe convert to what they stand for for clarity
##    * E (Everyone), E10+ (Everyone 10+), T (Teen), M (Mature 17+), AO (Adults Only 18+), RP (Rating Pending), K-A (Kids  to Adults), EC (Early Childhood)
### only nan's messing things up in year_of_release and user_scores, so let's just work on that
print('Datatypes:\n', df_games.dtypes)
print()
print('year_of_release list of values:\n', df_games['year_of_release'].unique())
print()
print('user_score list of values:\n', df_games['user_score'].unique())
print('user_score list of values:\n', df_games['user_score'].nunique())
print('user_score list of values:\n', df_games['user_score'].value_counts())
# Out:
# Datatypes:
#  name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object
#
# year_of_release list of values:
#  [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]
#
# user_score list of values:
#  ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
# ...

# %%
## convert year_of_release values from float to int

df_games['year_of_release'] = df_games['year_of_release'].astype('Int64')
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(5), object(5)
# memory usage: 1.4+ MB

# %%
## Calculating 'tbd's frequency of occurrence - to determine how we handle it
tbd = df_games[df_games['user_score'] == 'tbd'].value_counts().sum()
all_user_score = df_games['user_score'].value_counts().sum()
print('% of entire dataset values the value *tbd* represents:', round(tbd / all_user_score, 2) * 100, '%')
tbd_post_2006 = df_games[(df_games['user_score'] == 'tbd') & (df_games['year_of_release'] >= 2006)].value_counts().sum()
print('% of values the value *tbd* post 2006 represents:', round(tbd_post_2006 / post_2006_year_of_release, 2) * 100, '%')
df_games['user_score'] = pd.to_numeric(df_games['user_score'], errors='coerce')
mean_user_score_before = round(df_games['user_score'].mean(), 1)
median_user_score_before = round(df_games['user_score'].median(), 1)

# Results
print('User Score mean:', mean_user_score_before)
print('User Score median:', median_user_score_before)
print(df_games['user_score'].describe())
print()

# Calculating % values that fall into outlier land (<=4)
values_under_4 = len(df_games[df_games['user_score'] <= 4.0])
total_number_values = df_games['user_score'].count()
print('# of values under 4:', values_under_4)
print('Total # of values:', total_number_values)
print('% of values <= 4 (outliers):', (values_under_4 / total_number_values) * 100,'%')
print('Standard Deviation of "user_score":', df_games['user_score'].std())

# Box plot to see mean vs median vs outliers to get a handle on outliers potentially skewing mean
df_games['user_score'].plot(kind='box', title="Distribution of 'user_score' values")
plt.show()
df_games['user_score'].plot(kind='hist', title="Distribution of 'user_score' values")
# Out:
# % of entire dataset values the value *tbd* represents: 11.0 %
# % of values the value *tbd* post 2006 represents: 5.0 %
# User Score mean: 7.1
# User Score median: 7.5
# count    7590.000000
# mean        7.125046
# std         1.500006
# min         0.000000
# 25%         6.400000
# 50%         7.500000
# 75%         8.200000
# max         9.700000
# Name: user_score, dtype: float64
#
# # of values under 4: 373
# Total # of values: 7590
# % of values <= 4 (outliers): 4.9143610013175225 %
# Standard Deviation of "user_score": 1.5000060936257982
# <AxesSubplot:title={'center':"Distribution of 'user_score' values"}, ylabel='Frequency'>

# %%
# Calculating user_score mean with and without outliers to determine whether outliers have statistically significant influence on mean (which I may use to fill in missing values or not, depending)

user_score_mean_without_outliers = round(df_games[df_games['user_score'] > 4.0]['user_score'].mean(), 2)

print('User Score mean with outliers:', mean_user_score_before)
print('User Score mean without outliers:', user_score_mean_without_outliers)
# Out:
# User Score mean with outliers: 7.1
# User Score mean without outliers: 7.34

# %% [markdown]
# 2190 points of difference between using 7.1 and 7.34 as a mean to replace missing 9125 user_score values.
# 7.34 gets us much closer to median of 7.5

# %% [markdown]
# ### Description of 'user_score' column changes for 'tbd' value & overall missing values AND year_of_release data type
#
# * Converted year_of_release values from float to int to make 'year_of_release' values cleaner
#
# * In user_score column, 'tbd' is the highest occurring value (HOV) across total games at 2424 (or 10% of total games), 8X higher than the second HOV.
#
# * For total games released after 2006 (the range we will be working on) 'tbd' only accounts for 5%. Depending on missing values for other relevent columns, this may be low enough to Option A) Discard games with user_score's of 'tbd' from our dataset. Conversely, Option B) Replacing this low occurrence percentage with the mean value of this data column could be a better option. Option C) Since missing values comprise 120% of the user_score column values, even with such a small (.24) difference between means caluclated with & without outliers, imputing a mean value could skew results either way.
#
# * For now, I won't replace 'user_score' missing values (with the mean calculated without outliers) until I get to the section dealing with user_score influence (code to replace missing values with mean is below:

# %% [markdown]
# ### 2.3 Handling Missing Values

# %%
# Examine missing values
df_games.info()
df_games['year_of_release'].value_counts().sort_index().plot(kind='bar')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Observations
# The majority of Nan missing values lie in 'critic_score', 'user_score', and 'rating' columns.
#
# There is no specific information about how data was ontained or why values might be missing. Here are some general possiblities:
#
#     * Users did not provide a score or required information for score to be recorded/reported
#
#     * Critics did not provide a score or required information for score to be recorded/reported
#
#     * Users & Critics simply may not have wanted to provide scores; perhaps interface was too clunky, time consuming, perhaps scoring system didn't accurately reflect how they felt, perhaps just because they didn't feel like it. We don't know.
#
#     * Overall, the difference between the complete sales values & scores & ratings lie in who was providing the data. It makes sense for sales data to be complete since the company is tracking it itself. User & Critic scores are up to individuals to provide, so there will be more user to user variability about reporting their score.

# %%
# How many games were released prior to ESRB's rating system
df_games_pre_1994 = df_games[df_games['year_of_release'] < 1994]['year_of_release'].value_counts().sum()
print(df_games_pre_1994, 'games were released before ESRB ratings went into effect')
# Out:
# 367 games were released before ESRB ratings went into effect

# %% [markdown]
#     * For the 'ratings' column, since the ESRB assigns a rating to every video game, missing values in 'rating' likely lie in how the data was collected. A quick google search found that the ESRB began assigning video game ratings on September 16, 1994.

# %% [markdown]
#     * 367 only accounts for a small percentage of the 9949 missing 'rating' column values. It is unlikely that the 9 months not included in the math bring the 267 closer to 9949 (we do not have months, and rating were established 9 months into 1994).
#
#     * It is unclear why 40% of the 'rating' column's data is missing, however, since the ESRB presumably assigns each game a rating.

# %%
# Calculate percentage of missing values

df_games_total_rows = len(df_games)

critic_score_missing = df_games['critic_score'].isna().sum()
print('# of non-null values in "critic_score":', df_games['critic_score'].notna().sum())
print('# of missing values in "critic_score":', critic_score_missing)
print('% of values missing:', round(critic_score_missing / df_games_total_rows, 2) * 100, '%')
print()
user_score_missing = df_games['user_score'].isna().sum()
print('# of non-null values in "user_score":', df_games['user_score'].notna().sum())
print('# of missing values in "user_score":', user_score_missing)
print('% of values missing:', round((user_score_missing / df_games_total_rows) * 100, 2), '%')
print()
rating_missing = df_games['rating'].isna().sum()
print('# of non-null values in "rating":', df_games['rating'].notna().sum())
print('# of missing values in "rating":', rating_missing)
print('% of values missing:', round(rating_missing / df_games_total_rows, 2) * 100, '%')
# Out:
# # of non-null values in "critic_score": 8137
# # of missing values in "critic_score": 8578
# % of values missing: 51.0 %
#
# # of non-null values in "user_score": 7590
# # of missing values in "user_score": 9125
# % of values missing: 54.59 %
#
# # of non-null values in "rating": 9949
# # of missing values in "rating": 6766
# % of values missing: 40.0 %

# %%
# Analyze patterns in missing values 

#Grouping by RATINGS
## E (Everyone), E10+ (Everyone 10+), T (Teen), M (Mature 17+), AO (Adults Only 18+), RP (Rating Pending), K-A (Kids to Adults), EC (Early Childhood)

rating_filter_1 = df_games['rating'].value_counts()
print(rating_filter_1)
print()

# % of certain rating are missing user and/or critic score

df_user_critic_missing = df_games[df_games['user_score'].isna() | df_games['critic_score'].isna()]
rating_no_user_score = df_user_critic_missing[df_user_critic_missing['user_score'].isna()].groupby('rating').size().sort_values(ascending=False)
rating_no_critic_score = df_user_critic_missing[df_user_critic_missing['critic_score'].isna()].groupby('rating').size().sort_values(ascending=False)

print('# of Missing User Score by Rating:\n', rating_no_user_score.head(10))
print()
print('# of Missing Critic Score by Rating:\n', rating_no_critic_score.head(10))
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64
#
# # of Missing User Score by Rating:
#  rating
# E       1615
# T        400
# E10+     377
# M         45
# EC         7
# RP         1
# dtype: int64
#
# # of Missing Critic Score by Rating:
#  rating
# E       1182
# T        321
# E10+     302
# M         80
# EC         8
# K-A        2
# dtype: int64

# %% [markdown]
# ### MISSING VALUES
#
# * Since the bulk of noted 'rating' values fall into the E, T, M and E10+ ratings, I will focus on those to the exclusion of the others.
#
# ### OBSERVATIONS by 'rating' & 'user_score'
# * The E (Everyone) rating has the most missing values in the user_score & critic_score columns
# * T and E10+ ratings have the next highest, roughly 25% of the E rating missing values
# * M has the lowest (in the range we are looking at), ~10 - 25% lower than T & E10+ ratings
#
# * We do not get specific age information from the E rating. However, if we look at the distribution among T (Teens), E10+ (10 year olds and older) vs M (Mature 17+), we can infer certain results associated with age. Excluding E for now, if M is 17+, we can infer that T represents the ages 13 - 16 while E10+ is from the ages of 10 up. Taking T & E10+ together, they are 7 - 17 times higher than M/17 + users, or rather M users are 6% - 13% of T + E10+ + M users. If we apply this distribution to E users, we can approximate that 87 - 94% of E users are within the E10+ - T (10 - 16) range. From here, we might guess that the reason there are so many missing user_scores for E, T and E10+ rated games is that users between the ages of 10 - 16 (assuming most users are mostly playing the games their age is rated for) are those most responsible for not entering user_scores.
#
# * We can also contrast that with how much lower the missing values are for M/17+ users:
#
# * M-rated games: missing values account for <3% of total user_score values
# T-rated games: missing values account for 13.5% of total user_score values
# E10+-rated games: missing values account for 26.5% of total user_score values
#
# In summary: they're kids. Missing values for user_score increase proportionally as the age rating decreases. This also suggests that the younger the user, the likelier a missing user_score.

# %%
df_games['total_sales'] = df_games['eu_sales'] + df_games['na_sales'] + df_games['jp_sales'] + df_games['other_sales']
print('Correlation coefficient of Total Sales for All Games & Critic Score:', round(df_games['total_sales'].corr(df_games['critic_score']), 3))
print('Correlation coefficient of Total Sales for All Games & User Score:', round(df_games['total_sales'].corr(df_games['user_score']), 3))

total_sales = df_games['total_sales']
critic_score = df_games['critic_score']
user_score = df_games['user_score']
plt.scatter(user_score*10, total_sales, s=30, c='red', alpha=0.1)
plt.title('Total Sales for All Games vs User Score')
plt.xlabel('User Score')
plt.ylabel('Sales')
plt.xticks(range(0, 100, 10))
plt.ylim(0, 15)
plt.show()
print()
plt.scatter(critic_score, total_sales, s=30, c='blue', alpha=0.1)
plt.title('Total Sales for All Games vs Critic Score')
plt.xlabel('Critic Score')
plt.ylabel('Sales')
plt.xticks(range(0, 100, 10))
plt.ylim(0, 8)
plt.show()
# Out:
# Correlation coefficient of Total Sales for All Games & Critic Score: 0.246
# Correlation coefficient of Total Sales for All Games & User Score: 0.088

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good work with the correlation.
#
# </div>

# %%
# Platform by Year of Release with user & critic score
platform_by_critic_score = df_games.groupby('platform')[['critic_score', 'user_score', 'year_of_release']].mean()
platform_by_critic_score  = platform_by_critic_score.sort_values(by='year_of_release', ascending=False)
print(platform_by_critic_score)
# Out:
#           critic_score  user_score  year_of_release
# platform
# PS4          72.091270    6.748249      2015.145408
# XOne         73.325444    6.521429      2014.951417
# PSV          70.791667    7.336364      2014.132867
# WiiU         70.733333    6.904000      2013.659864
# 3DS          67.101190    6.831609      2013.126953
# PS3          70.382927    6.726568      2010.840735
# X360         68.616812    6.683540      2009.880682
# Wii          62.823932    6.742679      2008.966563
# PC           75.928671    7.062468      2008.914316
# PSP          67.424242    7.228266      2008.731769
# DS           63.761506    7.025194       2008.18529
# PS2          68.727273    7.626833      2004.583921
# XB           69.859310    7.500512      2003.636364
# GC           69.488839    7.597541      2003.400369
# GBA          67.372146    7.676863      2003.210851
# WS                 NaN         NaN           2000.0
# DC           87.357143    8.528571      1999.942308
# ...

# %% [markdown]
# ### OBSERVATIONS by Total Sales and 'user_score' & 'critic_score'
# First, we see the Pearson Correlation Coefficients for both user_score & critic_score relative to Total Sales:
#
#     * Correlation coefficient of Total Sales & Critic Score: 0.246
#     * Correlation coefficient of Total Sales & User Score: 0.088
#
# There is a weak-to-low-moderate correlation between how much Total Sales a game makes and how high the Critic Score is.
# There is a very weak correlation between how much Total Sales a game makes and how high the User Score is.
# We even see that Total Sales actually begins to fall when Critic score hits about 85 and User score hits about 90.

# %%
# Correlating Year of Release with Critic and User score values

year_of_release_values = df_games['year_of_release'].astype('float64') # 'year_of_release' Int64 values not playing nice with float64, so converting
missing_critic_scores = df_games['critic_score'].isna().astype('float64')
missing_user_scores = df_games['user_score'].isna().astype('float64')

# Correlation coefficient
print('Correlation coefficient of Year of Release & Critic Score:', year_of_release_values.corr(missing_critic_scores))
print('Correlation coefficient of Year of Release & User Score:', year_of_release_values.corr(missing_user_scores))
print()
# Filter for missing user & critic scores
df_user_missing = df_games[df_games['user_score'].isna()]
df_critic_missing = df_games[df_games['critic_score'].isna()]

# .groupby() 'year_of_release'
year_no_user_score = df_user_missing.groupby('year_of_release').size().sort_values(ascending=False).sort_index()
year_no_critic_score = df_critic_missing.groupby('year_of_release').size().sort_values(ascending=False).sort_index()

# success check by print()
print('# of Missing User Score by Year of Release 1980-1989:\n', year_no_user_score.head(10))
print()
print('# of Missing Critic Score by Year of Release 1980-1989:\n', year_no_critic_score.head(10))
print()
print('# of Missing User Score by Year of Release 2007 - 2016:\n', year_no_user_score.tail(10))
print()
print('# of Missing Critic Score by Year of Release 2007 - 2016:\n', year_no_critic_score.tail(10))
print()

# Plot the correlation of missing critic & user scores against 'year_of_release'

year_no_user_score.plot(kind='bar', title='# of Missing User Scores per Year', xlabel='Year of Release', ylabel='# of Missing User Scores')
plt.show()

year_no_critic_score.plot(kind='bar', title='# of Missing Critic Scores per Year', xlabel='Year of Release', ylabel='# of Missing Critic Scores', color='red')
plt.show()

print()
# Out:
# Correlation coefficient of Year of Release & Critic Score: -0.11703378122318858
# Correlation coefficient of Year of Release & User Score: -0.18646211397120657
#
# # of Missing User Score by Year of Release 1980-1989:
#  year_of_release
# 1980     9
# 1981    46
# 1982    36
# 1983    17
# 1984    14
# 1985    13
# 1986    21
# 1987    16
# 1988    14
# 1989    17
# dtype: int64
#
# # of Missing Critic Score by Year of Release 1980-1989:
#  year_of_release
# 1980     9
# 1981    46
# 1982    36
# 1983    17
# 1984    14
# 1985    13
# 1986    21
# 1987    16
# 1988    14
# 1989    17
# dtype: int64
#
# # of Missing User Score by Year of Release 2007 - 2016:
#  year_of_release
# 2007    568
# 2008    766
# 2009    812
# 2010    788
# 2011    635
# 2012    314
# 2013    240
# 2014    252
# 2015    309
# 2016    240
# dtype: int64
#
# # of Missing Critic Score by Year of Release 2007 - 2016:
#  year_of_release
# 2007    505
# 2008    712
# 2009    775
# 2010    755
# 2011    636
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good charts.
#
# </div>

# %% [markdown]
# ### OBSERVATIONS - missing user & critic scores by year of release
#
# * user & critic score missing values closely mirror each other year to year, in some years they are equal.
#
# * They both increase in 1994, decrease from 1994 - 2004, dramatically increase from 2005 - 2009, then experience a sharp drop/decrease in 2012 - 2016
#
# * I can't guess any more than I have why certain values are missing, but that they closely mirror each other is an interesting correlation. The increase in both in 1994 happens in the same year that the ESRB started rating games, so one could posit that the existence of game ratings affects the likelihood users and critics score the games.
#
# * If we had access to all the individual user scores, we could look at how many individual scores each game garnered relative to sales.

# %% [markdown]
# ### Handle missing user score, critic score and rating values based on analysis
#
# Overall, since:
#
#  1) Missing values for critic & user scores are around 51% & 55% respectively and missing ratings values are 40% of total possible values (16715)
#  2) This is a significant portion of possible values
#  3) The sample size that include values is still large/sufficient for analysis
#
# We gain little by filling missing user & critic scores or ratings with the median value
#
#
# ***Conclusion:***
#
#
# For analyses that require taking user & critic score and rating into account, I will exclude the games with missing values in these categories frrom analysis.

# %%
df_games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# total_sales           0
# dtype: int64

# %% [markdown]
# ### Handle missing name, genre and year of release values
#
# name: 16713 non-null
# platform: 16715 non-null
# year_of_release: 16446 non-null
# genre: 16713 non-null

# %%
df_games.isna().sum()
print(df_games.isna().sum() / df_games.shape[0]) # of missing values / total # of rows
# Out:
# name               0.000120
# platform           0.000000
# year_of_release    0.016093
# genre              0.000120
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# critic_score       0.513192
# user_score         0.545917
# rating             0.404786
# total_sales        0.000000
# dtype: float64

# %% [markdown]
# ***Decision***
#
# Since missing values account for a negligible % of name, genre and year of release, plus since they are categorical and not numerical (we gain nothing by guessing what these values are), I will exclude these values from analysis rather than substitute values in.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Excellent job with the handling of the missing values. Also with the charts.
#
# </div>

# %% [markdown]
# ### 2.4 Calculate Total Sales

# %%
# Calculate total sales across all regions and put them in a different column

df_games['total_sales'] = df_games['eu_sales'] + df_games['na_sales'] + df_games['jp_sales'] + df_games['other_sales']
print(df_games.head(10))
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good great with the calculation of the total sales.
#
# </div>

# %% [markdown]
# # Step 3: Analyzing Video Game Sales Data
#
# ## 3.1 Temporal Analysis of Game Releases
# We'll first examine the distribution of game releases across different years to understand our data's coverage and significance:

# %%
# Create a DataFrame with game releases by year
df_games_releases_by_year = df_games.groupby('year_of_release').size()

# %%
# Visualize the distribution of games across years

df_games_releases_by_year.plot(kind='bar', title='# of Game Releases by Year', xlabel='Year of Release', ylabel='# of Game Releases', color='green')
plt.show()

# %%
# Display summary statistics for each year
print(df_games_releases_by_year.head(37))
print()
print('Median # of releases:', df_games_releases_by_year.median())
print('Mean # of releases:', round(df_games_releases_by_year.mean(), 2))
df_games_releases_by_year.plot(kind='box')
plt.show()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      62
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# dtype: int64
#
# Median # of releases: 338.0
# Mean # of releases: 444.49

# %% [markdown]
# ***Observations:***
#
#
# * 2006 - 2011 had the highest number of game releases, all years exceeding 1000 releases
# * Of note, 2001 - 2002 shows the highest YoY increase in releases
# * Release #'s' peak in 2008-2009
# * From 2002 until 2011, releases stay high (we'll define 'high' as 750 and above, the high end of IQR3)
# * Of note, 2011 - 2012 shows the steepest drop off in releases
# * 2012 - 2016 releases remain under 750

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good answers.
#
# </div>

# %% [markdown]
# ### 3.2 Platform Sales Analysis Over Time
#
# Next we'll analyze how sales vary across platforms and years:

# %%
# Calculate total sales by platform and year
total_sales_platform_year = df_games.groupby(['platform', 'year_of_release'])['total_sales'].sum()
print(total_sales_platform_year.sort_index().head(20))
# Out:
# platform  year_of_release
# 2600      1980               11.38
#           1981               35.68
#           1982               28.88
#           1983                5.84
#           1984                0.27
#           1985                0.45
#           1986                0.67
#           1987                1.94
#           1988                0.74
#           1989                0.63
# 3DO       1994                0.02
#           1995                0.08
# 3DS       2011               63.20
#           2012               51.36
#           2013               56.57
#           2014               43.76
#           2015               27.78
#           2016               15.14
# DC        1998                3.38
#           1999                5.16
# Name: total_sales, dtype: float64

# %%
###### Create a heatmap of platform sales over time

### NOTE TO REVIEWER: We have not covered heatmap plots yet, so I had to learn from Dot. Worth passing on to whoever designs curriculum.
import seaborn as sns

plt.figure(figsize=(15, 8)) 

heatmap_data = df_games.pivot_table(
    values='total_sales',
    index='platform',
    columns='year_of_release',
    aggfunc='sum',
)
plt.xticks(rotation=45)
plt.xlabel('Platforms')
plt.ylabel('Year of Release')
plt.tight_layout()

sns.heatmap(heatmap_data, annot=True, fmt='.0f')
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='platform'>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good work with the heatmap.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# About the heatmap, I will share your thoughts about it.
#
# </div>

# %%
# Identify platforms with declining sales
total_sales_under_1 = df_games[((df_games['total_sales'] < 1) & (df_games['year_of_release'] == 2000)) | ((df_games['total_sales'] < 1) & (df_games['year_of_release'] == 2014))]
print(total_sales_under_1['platform'].unique())

total_sales_platform_year = total_sales_platform_year.sort_index()

# Adjusted heat map post 2006
year_of_release_post_2006 = df_games[df_games['year_of_release'] >= 2008]
plt.figure(figsize=(15, 8)) 
heatmap_data = year_of_release_post_2006.pivot_table(
    values='total_sales',
    index='platform',
    columns='year_of_release',
    aggfunc='sum',
)
plt.xticks(rotation=45)
plt.xlabel('Platforms')
plt.ylabel('Year of Release')
plt.tight_layout()

sns.heatmap(heatmap_data, annot=True, fmt='.0f')
# Out:
# ['XB' 'PS2' 'PS' 'PS3' 'Wii' 'XOne' 'PS4' 'X360' 'PC' 'GB' '3DS' 'WiiU'
#  'PSV' 'N64' 'WS' 'DC' 'PSP' 'GBA']
# <AxesSubplot:xlabel='year_of_release', ylabel='platform'>

# %% [markdown]
# ### Questions to Consider:
# - Which platforms show consistent sales over time?
# - Can you identify platforms that have disappeared from the market?
# - What's the typical lifecycle of a gaming platform?

# %% [markdown]
# ***Observations***
#
# All sales from all platforms up until 2016 are declining. SO it become important to determine what year range we want to look at.
# If we take into account the most successful platforms, even though their sales are declining through 2016, for 2017 releases, we will be modeling strategy on declining platforms regardless.
# If we take year ranges at the end of which platforms had their highest sales, those would be ranges worth modeling advertising strategy off of (i.e. where a platform is growing).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good answers.
#
# </div>

# %%
df_games['total_sales'].sum()

total_revenue_by_year = df_games.groupby('year_of_release')['total_sales'].sum()
total_revenue_by_year.plot(kind='bar', title='Total Sales for Gaming Industry by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='green')
plt.show()

# Broad growth from 2001 - 2010
# Declining sales 2011 - 2016

# %%
# Total historic sales by platform
total_sales_platform = df_games.groupby(['platform'])['total_sales'].sum().to_frame()
total_sales_platform.columns = ['total_sales']
print('Platforms by Total Sales, 1980-2016:\n\n', total_sales_platform.head(20).sort_values(by='total_sales', ascending=False))
# Out:
# Platforms by Total Sales, 1980-2016:
#
#            total_sales
# platform
# PS2           1255.77
# PS3            939.65
# DS             806.12
# PS             730.86
# GBA            317.85
# PS4            314.14
# PSP            294.05
# PC             259.52
# 3DS            259.00
# GB             255.46
# NES            251.05
# N64            218.68
# GC             198.93
# 2600            96.98
# GEN             30.77
# DC              15.95
# NG               1.44
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %% [markdown]
# ## 3.3 Determining Relevant Time Period
#
# Based on our analysis above, we'll determine the appropriate time period for predicting 2017 sales:

# %% [markdown]
# While the above sales reflect total sales since 1980, they do not take into account lifecycle of a platform, nor are they necessarily up to date. For instance, basing advertising strategy for 2017 on a platform that peaked almost 20 years ago (PS, 1998) might not be the right path. Narrowing dataset below to more recent years.

# %%
# Filtering by Top 4 overall games
top_4_platforms_revenue = df_games[df_games['platform'].isin(['PS2', 'PS3', 'DS', 'PS'])]
top_4_platforms_revenue = top_4_platforms_revenue[top_4_platforms_revenue['year_of_release'] >= 2001]

# Creating platform specific variables
top_4_platforms_revenue_ps = top_4_platforms_revenue[top_4_platforms_revenue['platform'] == 'PS']
top_4_platforms_revenue_ps2 = top_4_platforms_revenue[top_4_platforms_revenue['platform'] == 'PS2']
top_4_platforms_revenue_ps3 = top_4_platforms_revenue[top_4_platforms_revenue['platform'] == 'PS3']
top_4_platforms_revenue_ds = top_4_platforms_revenue[top_4_platforms_revenue['platform'] == 'DS']

# Grouping by total sales/year
top_4_platforms_revenue_ps_by_year = top_4_platforms_revenue_ps.groupby('year_of_release')['total_sales'].sum()
top_4_platforms_revenue_ps2_by_year = top_4_platforms_revenue_ps2.groupby('year_of_release')['total_sales'].sum()
top_4_platforms_revenue_ps3_by_year = top_4_platforms_revenue_ps3.groupby('year_of_release')['total_sales'].sum()
top_4_platforms_revenue_ds_by_year = top_4_platforms_revenue_ds.groupby('year_of_release')['total_sales'].sum()

# Plotting total sales/year for each platform

top_4_platforms_revenue_ps_by_year.plot(kind='bar', title='Total Sales for PS by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='red')
plt.show()
top_4_platforms_revenue_ps2_by_year.plot(kind='bar', title='Total Sales for PS2 by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='blue')
plt.show()
top_4_platforms_revenue_ps3_by_year.plot(kind='bar', title='Total Sales for PS3 by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='green')
plt.show()
top_4_platforms_revenue_ds_by_year.plot(kind='bar', title='Total Sales for DS by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='purple')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good charts.
#
# </div>

# %% [markdown]
# ***Options:***
#
# Based on the above data I have narrowed my paths to two options:
#
# Option A (contained in data above): Take individual platforms most successful (peak sales/growth) years and use those as reference.
#
#     Strength:
#     More data to look at peak growth
#
#     Weakness:
#     data spread out of different years, more code intensive to use inconsistent years
#
#     * Filter PS3 for year 2007 - 2013
#     * Filter DS for years 2005 - 2009
#     * Add Wii             2006 - 2009
#     * Add PS4             2014 - 2016
#     * Add X360            2006 - 2011
#     * Considering "old" data as over 10 years. The market has likely shifted with the advent of smart phones & social media),
#     * Removing PS2 for data being too old, PS both for data being too old and for small year of success/sales peak range
#
#
# Option B (contained in data above):
#
#     Strength:
#     Years/Time period more consistent, focused on specific peak sales ranges
#
#     Weakness:
#     Fewer data points
#
#     * Filter PS3 for years  2007 - 2009
#     * Filter DS for years   2007 - 2009
#     * Filter Wii for years  2007 - 2009
#     * Filter X360 for years 2007 - 2009
#
# Option C (see below):

# %%
# Platforms still selling in 2016 (PS4, XB1, 3DS).
# How long earlier platforms lasted before decline (to model expected lifetime).
# How many years after launch a platform usually hits peak (to anticipate Switch trajectory).

platforms_sales_2012_fwd = df_games[(df_games['year_of_release'] >= 2012) & (df_games['total_sales'] > 0)]

platforms_sales_2012_fwd_group = platforms_sales_2012_fwd.groupby(['platform'])['total_sales'].sum().to_frame()
platforms_sales_2012_fwd_group.columns = ['total_sales']
print('Platforms by Total Sales, 2012-2016:\n\n', platforms_sales_2012_fwd_group.head(20).sort_values(by='total_sales', ascending=False))
# Out:
# Platforms by Total Sales, 2012-2016:
#
#            total_sales
# platform
# PS4            314.14
# PS3            288.79
# X360           236.54
# 3DS            194.61
# XOne           159.32
# WiiU            82.19
# PC              62.65
# PSV             49.18
# Wii             35.37
# DS              12.55
# PSP             11.19

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done :)</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Great work updating the dataframe.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %%
# Visualize top platforms

# Filtering by Top 5 2012 - 2016 games
top_5_platforms_sales = platforms_sales_2012_fwd[platforms_sales_2012_fwd['platform'].isin(['PS4', 'PS3', 'X360', '3DS', 'XOne'])]
top_5_platforms_sales = top_5_platforms_sales[top_5_platforms_sales['year_of_release'] >= 2012]

# Creating platform specific variables
top_5_platforms_sales_ps4 = top_5_platforms_sales[top_5_platforms_sales['platform'] == 'PS4']
top_5_platforms_sales_ps3 = top_5_platforms_sales[top_5_platforms_sales['platform'] == 'PS3']
top_5_platforms_sales_x360 = top_5_platforms_sales[top_5_platforms_sales['platform'] == 'X360']
top_5_platforms_sales_3ds = top_5_platforms_sales[top_5_platforms_sales['platform'] == '3DS']
top_5_platforms_sales_xone = top_5_platforms_sales[top_5_platforms_sales['platform'] == 'XOne']

# Grouping by total sales/year
top_5_platforms_sales_ps4_by_year = top_5_platforms_sales_ps4.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_ps3_by_year = top_5_platforms_sales_ps3.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_x360_by_year = top_5_platforms_sales_x360.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_3ds_by_year = top_5_platforms_sales_3ds.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_xone_by_year = top_5_platforms_sales_xone.groupby('year_of_release')['total_sales'].sum()

# Plotting total sales/year for each platform

top_5_platforms_sales_ps4_by_year.plot(kind='bar', title='Total Sales for PS4 by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='red')
plt.show()
top_5_platforms_sales_ps3_by_year.plot(kind='bar', title='Total Sales for PS3 by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='blue')
plt.show()
top_5_platforms_sales_x360_by_year.plot(kind='bar', title='Total Sales for X360 by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='green')
plt.show()
top_5_platforms_sales_3ds_by_year.plot(kind='bar', title='Total Sales for 3DS by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='purple')
plt.show()
top_5_platforms_sales_xone_by_year.plot(kind='bar', title='Total Sales for XOne by Year', xlabel='Year of Release', ylabel='Sales (in millions of $)', color='yellow')
plt.show()

# %% [markdown]
# ### Document My Decision:
# - What years did I select and why?
#
#   * Option C: PS4, PS3, 3DS, XOne, X360 (2012 - 2016) (data contained in graphs above):
#     * Weakness: does not overall focus on peak sales per platform, learn from all past successes, even if they are not recent
#
# - This period reflects current market conditions because:
#   * it's the most recent data and thus most relevant to 2017. It takes into account both platforms dying out and growing/stable; we can learn from both.
#   * It is well into the era/advent of social media, smartphone ubiquity and mobile phone use
#
# - The factors that influenced my decision are:
#
#         * Recent data, especially given technology shifting (social media, smart phone upgrades & overall use/integration into society), seems more relevant than data sourced from years before these market influencers existed in a meaningful way.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good decision.
#
# </div>

# %% [markdown]
# ## 3.4 Platform Performance Analysis
#
# Using our selected time period, we'll analyze platform performance:

# %%
# Analyze platform sales trends

top_5_platforms_sales_ps4_by_year = top_5_platforms_sales_ps4.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_ps3_by_year = top_5_platforms_sales_ps3.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_x360_by_year = top_5_platforms_sales_x360.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_3ds_by_year = top_5_platforms_sales_3ds.groupby('year_of_release')['total_sales'].sum()
top_5_platforms_sales_xone_by_year = top_5_platforms_sales_xone.groupby('year_of_release')['total_sales'].sum()

# %%
# Calculate year-over-year growth for each platform

# PS4 YoY growth
year_2012_ps4 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2012) & (top_5_platforms_sales['platform'] == 'PS4')]
year_2012_ps4_sales = year_2012_ps4['total_sales'].sum()
print('2012:', round(year_2012_ps4_sales, 2))

year_2013_ps4 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2013) & (top_5_platforms_sales['platform'] == 'PS4')]
year_2013_ps4_sales = year_2013_ps4['total_sales'].sum()
print('2013:', round(year_2013_ps4_sales, 2))

year_2014_ps4 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2014) & (top_5_platforms_sales['platform'] == 'PS4')]
year_2014_ps4_sales = year_2014_ps4['total_sales'].sum()
print('2014:', round(year_2014_ps4_sales, 2))

year_2015_ps4 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2015) & (top_5_platforms_sales['platform'] == 'PS4')]
year_2015_ps4_sales = year_2015_ps4['total_sales'].sum()
print('2015:', round(year_2015_ps4_sales, 2))

year_2016_ps4 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2016) & (top_5_platforms_sales['platform'] == 'PS4')]
year_2016_ps4_sales = year_2016_ps4['total_sales'].sum()
print('2016:', round(year_2016_ps4_sales, 2))
print()

ps4_yoy_2012_2013 = ((year_2013_ps4_sales - year_2012_ps4_sales) / year_2012_ps4_sales)
ps4_yoy_2013_2014 = ((year_2014_ps4_sales - year_2013_ps4_sales) / year_2013_ps4_sales)
ps4_yoy_2014_2015 = ((year_2015_ps4_sales - year_2014_ps4_sales) / year_2014_ps4_sales)
ps4_yoy_2015_2016 = ((year_2016_ps4_sales - year_2015_ps4_sales) / year_2015_ps4_sales)

print('2012 - 2013 YoY %:', round(ps4_yoy_2012_2013 * 100, 2))
print('2013 - 2014 YoY %:', round(ps4_yoy_2013_2014 * 100, 2))
print('2014 - 2015 YoY %:', round(ps4_yoy_2014_2015 * 100, 2))
print('2015 - 2016 YoY %:', round(ps4_yoy_2015_2016 * 100, 2))
# Out:
# 2012: 0.0
# 2013: 25.99
# 2014: 100.0
# 2015: 118.9
# 2016: 69.25
#
# 2012 - 2013 YoY %: inf
# 2013 - 2014 YoY %: 284.76
# 2014 - 2015 YoY %: 18.9
# 2015 - 2016 YoY %: -41.76
# /tmp/ipykernel_52/1834827777.py:25: RuntimeWarning: divide by zero encountered in double_scalars
#   ps4_yoy_2012_2013 = ((year_2013_ps4_sales - year_2012_ps4_sales) / year_2012_ps4_sales)

# %%
# PS3 YoY growth
year_2012_ps3 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2012) & (top_5_platforms_sales['platform'] == 'PS3')]
year_2012_ps3_sales = year_2012_ps3['total_sales'].sum()
print('2012:', round(year_2012_ps3_sales, 2))

year_2013_ps3 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2013) & (top_5_platforms_sales['platform'] == 'PS3')]
year_2013_ps3_sales = year_2013_ps3['total_sales'].sum()
print('2013:', round(year_2013_ps3_sales, 2))

year_2014_ps3 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2014) & (top_5_platforms_sales['platform'] == 'PS3')]
year_2014_ps3_sales = year_2014_ps3['total_sales'].sum()
print('2014:', round(year_2014_ps3_sales, 2))

year_2015_ps3 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2015) & (top_5_platforms_sales['platform'] == 'PS3')]
year_2015_ps3_sales = year_2015_ps3['total_sales'].sum()
print('2015:', round(year_2015_ps3_sales, 2))

year_2016_ps3 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2016) & (top_5_platforms_sales['platform'] == 'PS3')]
year_2016_ps3_sales = year_2016_ps3['total_sales'].sum()
print('2016:', round(year_2016_ps3_sales, 2))
print()

ps3_yoy_2012_2013 = ((year_2013_ps3_sales - year_2012_ps3_sales) / year_2012_ps3_sales)
ps3_yoy_2013_2014 = ((year_2014_ps3_sales - year_2013_ps3_sales) / year_2013_ps3_sales)
ps3_yoy_2014_2015 = ((year_2015_ps3_sales - year_2014_ps3_sales) / year_2014_ps3_sales)
ps3_yoy_2015_2016 = ((year_2016_ps3_sales - year_2015_ps3_sales) / year_2015_ps3_sales)

print('2012 - 2013 YoY %:', round(ps3_yoy_2012_2013 * 100, 2))
print('2013 - 2014 YoY %:', round(ps3_yoy_2013_2014 * 100, 2))
print('2014 - 2015 YoY %:', round(ps3_yoy_2014_2015 * 100, 2))
print('2015 - 2016 YoY %:', round(ps3_yoy_2015_2016 * 100, 2))
# Out:
# 2012: 107.36
# 2013: 113.25
# 2014: 47.76
# 2015: 16.82
# 2016: 3.6
#
# 2012 - 2013 YoY %: 5.49
# 2013 - 2014 YoY %: -57.83
# 2014 - 2015 YoY %: -64.78
# 2015 - 2016 YoY %: -78.6

# %%
# X360 YoY growth
year_2012_x360 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2012) & (top_5_platforms_sales['platform'] == 'X360')]
year_2012_x360_sales = year_2012_x360['total_sales'].sum()
print('2012:', round(year_2012_x360_sales, 2))

year_2013_x360 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2013) & (top_5_platforms_sales['platform'] == 'X360')]
year_2013_x360_sales = year_2013_x360['total_sales'].sum()
print('2013:', round(year_2013_x360_sales, 2))

year_2014_x360 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2014) & (top_5_platforms_sales['platform'] == 'X360')]
year_2014_x360_sales = year_2014_x360['total_sales'].sum()
print('2014:', round(year_2014_x360_sales, 2))

year_2015_x360 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2015) & (top_5_platforms_sales['platform'] == 'X360')]
year_2015_x360_sales = year_2015_x360['total_sales'].sum()
print('2015:', round(year_2015_x360_sales, 2))

year_2016_x360 = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2016) & (top_5_platforms_sales['platform'] == 'X360')]
year_2016_x360_sales = year_2016_x360['total_sales'].sum()
print('2016:', round(year_2016_x360_sales, 2))
print()

x360_yoy_2012_2013 = ((year_2013_x360_sales - year_2012_x360_sales) / year_2012_x360_sales)
x360_yoy_2013_2014 = ((year_2014_x360_sales - year_2013_x360_sales) / year_2013_x360_sales)
x360_yoy_2014_2015 = ((year_2015_x360_sales - year_2014_x360_sales) / year_2014_x360_sales)
x360_yoy_2015_2016 = ((year_2016_x360_sales - year_2015_x360_sales) / year_2015_x360_sales)

print('2012 - 2013 YoY %:', round(x360_yoy_2012_2013 * 100, 2))
print('2013 - 2014 YoY %:', round(x360_yoy_2013_2014 * 100, 2))
print('2014 - 2015 YoY %:', round(x360_yoy_2014_2015 * 100, 2))
print('2015 - 2016 YoY %:', round(x360_yoy_2015_2016 * 100, 2))
# Out:
# 2012: 99.74
# 2013: 88.58
# 2014: 34.74
# 2015: 11.96
# 2016: 1.52
#
# 2012 - 2013 YoY %: -11.19
# 2013 - 2014 YoY %: -60.78
# 2014 - 2015 YoY %: -65.57
# 2015 - 2016 YoY %: -87.29

# %%
# 3DS YoY growth
year_2012_3ds = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2012) & (top_5_platforms_sales['platform'] == '3DS')]
year_2012_3ds_sales = year_2012_3ds['total_sales'].sum()
print('2012:', round(year_2012_3ds_sales, 2))

year_2013_3ds = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2013) & (top_5_platforms_sales['platform'] == '3DS')]
year_2013_3ds_sales = year_2013_3ds['total_sales'].sum()
print('2013:', round(year_2013_3ds_sales, 2))

year_2014_3ds = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2014) & (top_5_platforms_sales['platform'] == '3DS')]
year_2014_3ds_sales = year_2014_3ds['total_sales'].sum()
print('2014:', round(year_2014_3ds_sales, 2))

year_2015_3ds = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2015) & (top_5_platforms_sales['platform'] == '3DS')]
year_2015_3ds_sales = year_2015_3ds['total_sales'].sum()
print('2015:', round(year_2015_3ds_sales, 2))

year_2016_3ds = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2016) & (top_5_platforms_sales['platform'] == '3DS')]
year_2016_3ds_sales = year_2016_3ds['total_sales'].sum()
print('2016:', round(year_2016_3ds_sales, 2))
print()

yoy_2012_2013_3ds = ((year_2013_3ds_sales - year_2012_3ds_sales) / year_2012_3ds_sales)
yoy_2013_2014_3ds = ((year_2014_3ds_sales - year_2013_3ds_sales) / year_2013_3ds_sales)
yoy_2014_2015_3ds = ((year_2015_3ds_sales - year_2014_3ds_sales) / year_2014_3ds_sales)
yoy_2015_2016_3ds = ((year_2016_3ds_sales - year_2015_3ds_sales) / year_2015_3ds_sales)

print('2012 - 2013 YoY %:', round(yoy_2012_2013_3ds * 100, 2))
print('2013 - 2014 YoY %:', round(yoy_2013_2014_3ds * 100, 2))
print('2014 - 2015 YoY %:', round(yoy_2014_2015_3ds * 100, 2))
print('2015 - 2016 YoY %:', round(yoy_2015_2016_3ds * 100, 2))
# Out:
# 2012: 51.36
# 2013: 56.57
# 2014: 43.76
# 2015: 27.78
# 2016: 15.14
#
# 2012 - 2013 YoY %: 10.14
# 2013 - 2014 YoY %: -22.64
# 2014 - 2015 YoY %: -36.52
# 2015 - 2016 YoY %: -45.5

# %%
# XOne YoY growth
year_2012_xone = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2012) & (top_5_platforms_sales['platform'] == 'XOne')]
year_2012_xone_sales = year_2012_xone['total_sales'].sum()
print('2012:', round(year_2012_xone_sales, 2))

year_2013_xone = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2013) & (top_5_platforms_sales['platform'] == 'XOne')]
year_2013_xone_sales = year_2013_xone['total_sales'].sum()
print('2013:', round(year_2013_xone_sales, 2))

year_2014_xone = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2014) & (top_5_platforms_sales['platform'] == 'XOne')]
year_2014_xone_sales = year_2014_xone['total_sales'].sum()
print('2014:', round(year_2014_xone_sales, 2))

year_2015_xone = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2015) & (top_5_platforms_sales['platform'] == 'XOne')]
year_2015_xone_sales = year_2015_xone['total_sales'].sum()
print('2015:', round(year_2015_xone_sales, 2))

year_2016_xone = top_5_platforms_sales[(top_5_platforms_sales['year_of_release'] == 2016) & (top_5_platforms_sales['platform'] == 'XOne')]
year_2016_xone_sales = year_2016_xone['total_sales'].sum()
print('2016:', round(year_2016_xone_sales, 2))
print()

xone_yoy_2012_2013 = ((year_2013_xone_sales - year_2012_xone_sales) / year_2012_xone_sales)
xone_yoy_2013_2014 = ((year_2014_xone_sales - year_2013_xone_sales) / year_2013_xone_sales)
xone_yoy_2014_2015 = ((year_2015_xone_sales - year_2014_xone_sales) / year_2014_xone_sales)
xone_yoy_2015_2016 = ((year_2016_xone_sales - year_2015_xone_sales) / year_2015_xone_sales)

print('2012 - 2013 YoY %:', round(xone_yoy_2012_2013 * 100, 2))
print('2013 - 2014 YoY %:', round(xone_yoy_2013_2014 * 100, 2))
print('2014 - 2015 YoY %:', round(xone_yoy_2014_2015 * 100, 2))
print('2015 - 2016 YoY %:', round(xone_yoy_2015_2016 * 100, 2))
# Out:
# 2012: 0.0
# 2013: 18.96
# 2014: 54.07
# 2015: 60.14
# 2016: 26.15
#
# 2012 - 2013 YoY %: inf
# 2013 - 2014 YoY %: 185.18
# 2014 - 2015 YoY %: 11.23
# 2015 - 2016 YoY %: -56.52
# /tmp/ipykernel_52/4115378330.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   xone_yoy_2012_2013 = ((year_2013_xone_sales - year_2012_xone_sales) / year_2012_xone_sales)

# %%
# Sort platforms by total sales

top_5_platforms_sales = df_games[df_games['platform'].isin(['PS4', 'PS3', 'X360', '3DS', 'XOne'])]
top_5_platforms_sales = top_5_platforms_sales[top_5_platforms_sales['year_of_release'] >= 2012]

print('Top 5 platforms sorted by total sales 2012 - 2016:\n\n', top_5_platforms_sales.groupby(['platform'])['total_sales'].sum().sort_values(ascending=False))
# Out:
# Top 5 platforms sorted by total sales 2012 - 2016:
#
#  platform
# PS4     314.14
# PS3     288.79
# X360    236.54
# 3DS     194.61
# XOne    159.32
# Name: total_sales, dtype: float64

# %%
# Your code here to calculate and visualize platform growth rates
ps4_12_13 = round(ps4_yoy_2012_2013 * 100, 2)
ps4_13_14 = round(ps4_yoy_2013_2014 * 100, 2)
ps4_14_15 = round(ps4_yoy_2014_2015 * 100, 2)
ps4_15_16 = round(ps4_yoy_2015_2016 * 100, 2)

ps3_12_13 = round(ps3_yoy_2012_2013 * 100, 2)
ps3_13_14 = round(ps3_yoy_2013_2014 * 100, 2)
ps3_14_15 = round(ps3_yoy_2014_2015 * 100, 2)
ps3_15_16 = round(ps3_yoy_2015_2016 * 100, 2)

x360_12_13 = round(x360_yoy_2012_2013 * 100, 2)
x360_13_14 = round(x360_yoy_2013_2014 * 100, 2)
x360_14_15 = round(x360_yoy_2014_2015 * 100, 2)
x360_15_16 = round(x360_yoy_2015_2016 * 100, 2)

ds3_12_13 = round(yoy_2012_2013_3ds * 100, 2)
ds3_13_14 = round(yoy_2013_2014_3ds * 100, 2)
ds3_14_15 = round(yoy_2014_2015_3ds * 100, 2)
ds3_15_16 = round(yoy_2015_2016_3ds * 100, 2)

xone_12_13 = round(xone_yoy_2012_2013 * 100, 2)
xone_13_14 = round(xone_yoy_2013_2014 * 100, 2)
xone_14_15 = round(xone_yoy_2014_2015 * 100, 2)
xone_15_16 = round(xone_yoy_2015_2016 * 100, 2)

ps4_growth = [ps4_12_13, ps4_12_13, ps4_14_15, ps4_15_16]
ps3_growth = [ps3_12_13, ps3_13_14, ps3_14_15, ps3_15_16]
growth_3ds = [x360_12_13, x360_13_14, x360_14_15, x360_15_16]
x360_growth = [ds3_12_13, ds3_13_14, ds3_14_15, ds3_15_16]
xone_growth = [xone_12_13, xone_13_14, xone_14_15, xone_15_16]

df_top_5_platforms = pd.DataFrame({
    'PS4': ps4_growth,
    'PS3': ps3_growth,
    'X360': x360_growth,
    '3DS': growth_3ds,
    'XOne': xone_growth},
    index=['12-13', '13-14', '14-15', '15-16']
)
print('YoY growth:\n', df_top_5_platforms)
print()

df_top_5_platforms.plot(kind='line', title='Year over Year % Growth/Decline', xlabel='Year over Year (YoY)', ylabel='Sales (in millions of $)')
plt.show()

# Plotting total sales/year for each platform
df_top_5_platforms_sales_ps4_by_year = top_5_platforms_sales_ps4_by_year.to_frame().reset_index()
df_top_5_platforms_sales_ps3_by_year = top_5_platforms_sales_ps3_by_year.to_frame().reset_index()
df_top_5_platforms_sales_x360_by_year = top_5_platforms_sales_x360_by_year.to_frame().reset_index()
df_top_5_platforms_sales_3ds_by_year = top_5_platforms_sales_3ds_by_year.to_frame().reset_index()
df_top_5_platforms_sales_xone_by_year = top_5_platforms_sales_xone_by_year.to_frame().reset_index()

#print('Top 5 platforms sorted by total sales 2012 - 2016:\n\n', top_5_platforms_sales.groupby(['platform'])['total_sales'].sum().sort_values(ascending=False))
#print('Top 5 platforms sorted by total sales 2012 - 2016:\n\n', top_5_platforms_sales.groupby(['year_of_release'])['total_sales'].sum().sort_values(ascending=False))
# Out:
# YoY growth:
#           PS4    PS3   X360    3DS    XOne
# 12-13    inf   5.49  10.14 -11.19     inf
# 13-14    inf -57.83 -22.64 -60.78  185.18
# 14-15  18.90 -64.78 -36.52 -65.57   11.23
# 15-16 -41.76 -78.60 -45.50 -87.29  -56.52

# %%
# Plotting sales by platform & year (2012-2016)

print(df_top_5_platforms_sales_ps4_by_year)
print(df_top_5_platforms_sales_ps3_by_year)
print(df_top_5_platforms_sales_x360_by_year)
print(df_top_5_platforms_sales_3ds_by_year)
print(df_top_5_platforms_sales_xone_by_year)

plt.figure(figsize=(15, 8))
ax = df_top_5_platforms_sales_ps4_by_year.plot(
    kind='line', 
    color='red', 
    x='year_of_release', 
    y='total_sales', 
    legend=False)

df_top_5_platforms_sales_ps3_by_year.plot(
    kind='line', 
    color='blue', 
    x='year_of_release', 
    y='total_sales', 
    legend=False,
    ax=ax)

df_top_5_platforms_sales_x360_by_year.plot(
    kind='line', 
    color='green', 
    x='year_of_release', 
    y='total_sales', 
    legend=False,
    ax=ax)

df_top_5_platforms_sales_3ds_by_year.plot(
    kind='line', 
    color='purple', 
    x='year_of_release', 
    y='total_sales', 
    legend=False,
    ax=ax)

df_top_5_platforms_sales_xone_by_year.plot(
    kind='line', 
    color='yellow', 
    x='year_of_release', 
    y='total_sales', 
    legend=False,
    ax=ax)

# Because I need a laugh
plt.annotate("Oh nooooooo!", 
             xy=(2014, 50),  # Point to annotate
             xytext=(2015.4, 70),  # Text position
             fontsize=12, 
             color='red',
             rotation=-52)

plt.annotate("Wheeeee!", 
             xy=(2013, 75), 
             xytext=(2013, 90),
             fontsize=12, 
             color='blue',
             rotation=-58)

plt.xticks([2012, 2013, 2014, 2015, 2016])
plt.title('Total Sales by Platform and Year')
plt.xlabel('Year of Release')
plt.ylabel('Sales (in millions of $)')
plt.legend(['PS4', 'PS3', 'X360', '3DS', 'XOne'])
plt.show()
# Out:
#    year_of_release  total_sales
# 0             2013        25.99
# 1             2014       100.00
# 2             2015       118.90
# 3             2016        69.25
#    year_of_release  total_sales
# 0             2012       107.36
# 1             2013       113.25
# 2             2014        47.76
# 3             2015        16.82
# 4             2016         3.60
#    year_of_release  total_sales
# 0             2012        99.74
# 1             2013        88.58
# 2             2014        34.74
# 3             2015        11.96
# 4             2016         1.52
#    year_of_release  total_sales
# 0             2012        51.36
# 1             2013        56.57
# 2             2014        43.76
# 3             2015        27.78
# 4             2016        15.14
#    year_of_release  total_sales
# 0             2013        18.96
# 1             2014        54.07
# 2             2015        60.14
# 3             2016        26.15

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Great work with the `3.4 Platform Performance Analysis` stage.
#
# </div>

# %% [markdown]
# ## 3.5 Sales Distribution Analysis
#
# Let's examine the distribution of sales across platforms:

# %%
print(df_top_5_platforms_sales_ps4_by_year)
print(df_top_5_platforms_sales_ps4_by_year.info())
# Out:
#    year_of_release  total_sales
# 0             2013        25.99
# 1             2014       100.00
# 2             2015       118.90
# 3             2016        69.25
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year_of_release  4 non-null      int64
#  1   total_sales      4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 192.0 bytes
# None

# %%
# Create box plot of sales by platform

df_top_5_platforms_sales_ps4_by_year['total_sales'].plot(
    kind='box', 
    color='red',
    title='Total PS4 Sales 2012 - 2016', 
    xlabel='',
    ylabel='Sales (in millions of $)'
)
plt.show()

df_top_5_platforms_sales_ps3_by_year['total_sales'].plot(
    kind='box', 
    color='blue',
    title='PS3 Sales 2012 - 2016', 
    xlabel='',
    ylabel='Total Sales (in millions of $)'
)
plt.show()

df_top_5_platforms_sales_x360_by_year['total_sales'].plot(
    kind='box', 
    color='green',
    title='X360 Sales 2012 - 2016', 
    xlabel='',
    ylabel='Total Sales (in millions of $)'
)
plt.show()

df_top_5_platforms_sales_3ds_by_year['total_sales'].plot(
    kind='box', 
    color='purple',
    title='3DS Sales 2012 - 2016', 
    xlabel='',
    ylabel='Total Sales (in millions of $)'
)
plt.show()

df_top_5_platforms_sales_xone_by_year['total_sales'].plot(
    kind='box', 
    color='yellow',
    title='XOne Sales 2012 - 2016', 
    xlabel='',
    ylabel='Total Sales (in millions of $)'
)
plt.show()

combined_data = [] # empty list
for platform, data in [
    ('PS4', df_top_5_platforms_sales_ps4_by_year['total_sales']),
    ('PS3', df_top_5_platforms_sales_ps3_by_year['total_sales']),
    ('X360', df_top_5_platforms_sales_x360_by_year['total_sales']),
    ('3DS', df_top_5_platforms_sales_3ds_by_year['total_sales']),
    ('XOne', df_top_5_platforms_sales_xone_by_year['total_sales'])
]:
    for value in data:
        combined_data.append({'Platform': platform, 'Total_Sales': value})

df_combined = pd.DataFrame(combined_data)
df_combined.boxplot(column='Total_Sales', by='Platform', figsize=(12, 6), grid=False)
plt.title('Sales Distribution by Platform (2012-2016)')
plt.show()

# %% [markdown]
# ![Screen Shot 2025-08-27 at 2.06.56 PM.png](attachment:063483fe-706e-48fc-888d-baef2c65099d.png)

# %%
# Calculate detailed statistics for each platform

print('PS4 Sales Statistics:\n', round(df_top_5_platforms_sales_ps4_by_year['total_sales'].describe(), 2))
print()
print('PS3 Sales Statistics:\n', round(df_top_5_platforms_sales_ps3_by_year['total_sales'].describe(), 2))
print()
print('X360 Sales Statistics:\n', round(df_top_5_platforms_sales_x360_by_year['total_sales'].describe(), 2))
print()
print('3DS Sales Statistics:\n', round(df_top_5_platforms_sales_3ds_by_year['total_sales'].describe(), 2))
print()
print('XOne Sales Statistics:\n', round(df_top_5_platforms_sales_xone_by_year['total_sales'].describe(), 2))
# Out:
# PS4 Sales Statistics:
#  count      4.00
# mean      78.54
# std       40.57
# min       25.99
# 25%       58.44
# 50%       84.62
# 75%      104.72
# max      118.90
# Name: total_sales, dtype: float64
#
# PS3 Sales Statistics:
#  count      5.00
# mean      57.76
# std       50.62
# min        3.60
# 25%       16.82
# 50%       47.76
# 75%      107.36
# max      113.25
# Name: total_sales, dtype: float64
#
# X360 Sales Statistics:
#  count     5.00
# mean     47.31
# std      44.60
# min       1.52
# 25%      11.96
# 50%      34.74
# 75%      88.58
# max      99.74
# Name: total_sales, dtype: float64
#
# 3DS Sales Statistics:
#  count     5.00
# mean     38.92
# std      17.17
# min      15.14
# 25%      27.78
# 50%      43.76
# 75%      51.36
# max      56.57
# Name: total_sales, dtype: float64
#
# XOne Sales Statistics:
#  count     4.00
# mean     39.83
# std      20.31
# min      18.96
# 25%      24.35
# 50%      40.11
# 75%      55.59
# max      60.14
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good work.
#
# </div>

# %% [markdown]
# ## 3.6 Review Score Impact Analysis

# %% [markdown]
# ### Choosing a popular platform based on my previous analysis
# I'll choose PS4. Sales are declining across the board, but PS4 has the highest sales overall, the highest sales going in 2016, and is not only one of the most recent platforms to hit the market, but it stands on the shoulders of its very successful predecessors, PS, PS2 and PS3. These elements make it a useful platform to analyze.

# %%
# Create scatter plots for both critic and user scores
ps4 = top_5_platforms_sales[top_5_platforms_sales['platform'] == 'PS4']

# %%
# User Scores
ps4.plot(x='user_score', 
         y='total_sales', 
         figsize=(8,6),
         kind='scatter', 
         title='PS4 User Score/Sales Correlations',
         ylabel='Total Sales',
         xlabel='User Score',
         color='red',
         alpha=.5
)
plt.show()

# %%
# Critic Scores

ps4.plot(x='critic_score',
         y='total_sales',  
         figsize=(8,6),
         kind='scatter', 
         title='PS4 Critic Score/Sales Correlations',
         ylabel='Total Sales',
         xlabel='Critic Score',
         color='blue',
         alpha=.5
)
plt.show()

# %%
# Calculate correlations
print('Correlation coefficient of Total Sales for PS4 & User Score:', round(ps4['total_sales'].corr(ps4['user_score']), 3))
print('Correlation coefficient of Total Sales for PS4 & Critic Score:', round(ps4['total_sales'].corr(ps4['critic_score']), 3))
# Out:
# Correlation coefficient of Total Sales for PS4 & User Score: -0.032
# Correlation coefficient of Total Sales for PS4 & Critic Score: 0.407

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job with the review score impact analysis.
#
# </div>

# %% [markdown]
# There is negligible negative correlation between PS4 all region total sales and User Score
# There is a moderate positive correlation between PS4 all region total sales and Critic Score

# %% [markdown]
# ## 3.7 Cross-Platform Comparison
#
# Compare sales performance of games across different platforms:

# %%
# Find games released on multiple platforms

multi_platform_games = []
name_count = df_games['name'].value_counts()

for name, count in name_count.items():
    if count > 1:
        multi_platform_games.append(name)

# %% [markdown]
# ![Sales falling.png](attachment:507310db-5fe6-4e54-beee-2542eb23083c.png)

# %%
# Compare sales across platforms for these games
# Analyze and visualize cross-platform performance

df_games_multi_platform = df_games[df_games['name'].isin(multi_platform_games)]
pivot_data = df_games_multi_platform.pivot_table(
    index = 'name',
    columns = 'platform',
    values = 'total_sales',
    aggfunc='sum'
)
print(pivot_data.head())

total_sales_multi_platform = pivot_data.sum().sort_values(ascending=False)
print('Total Multi-Platform Game Sales by Platform (in millions of $),:\n', total_sales_multi_platform)

total_sales_multi_platform.plot(
    kind='bar', 
    title='Total Multi-Platform Game Sales by Platform (in millions of $)', 
    xlabel='Game', 
    ylabel='Sales (in millions of $)', 
    color='green')
plt.show()
print()


total_multi_platform_games = pivot_data.count().sort_values(ascending=False)
print('# of Multi-Platform Games by Platform,:\n', total_multi_platform_games)
total_multi_platform_games.plot(
    kind='bar', 
    title='# of Multi-Platform Games', 
    xlabel='Game', 
    ylabel='# of Multi-Platform Games', 
    color='blue')
plt.show()
print()

mean_sales_multi_platform = pivot_data.mean().sort_values(ascending=False)
print('Average Sales per Multi-Platform Game by Platform (in millions of $):\n', mean_sales_multi_platform)
mean_sales_multi_platform.plot(
    kind='bar', 
    title='Average Sales per Multi-Platform Game by Platform (in millions of $)', 
    xlabel='Game', 
    ylabel='Average Sales per Multi-Platform Game', 
    color='purple')
plt.show()
print()
# Out:
# platform                          2600   3DS  DC    DS  GB  GBA    GC  GEN  \
# name
#  Frozen: Olaf's Quest              NaN  0.59 NaN  0.51 NaN  NaN   NaN  NaN
# 007: Quantum of Solace             NaN   NaN NaN  0.13 NaN  NaN   NaN  NaN
# 007: The World is not Enough       NaN   NaN NaN   NaN NaN  NaN   NaN  NaN
# 11eyes: CrossOver                  NaN   NaN NaN   NaN NaN  NaN   NaN  NaN
# 18 Wheeler: American Pro Trucker   NaN   NaN NaN   NaN NaN  NaN  0.11  NaN
#
# platform                           N64  NES  ...   PSP  PSV  SAT  SNES  WS  \
# name                                         ...
#  Frozen: Olaf's Quest              NaN  NaN  ...   NaN  NaN  NaN   NaN NaN
# 007: Quantum of Solace             NaN  NaN  ...   NaN  NaN  NaN   NaN NaN
# 007: The World is not Enough      1.56  NaN  ...   NaN  NaN  NaN   NaN NaN
# 11eyes: CrossOver                  NaN  NaN  ...  0.02  NaN  NaN   NaN NaN
# 18 Wheeler: American Pro Trucker   NaN  NaN  ...   NaN  NaN  NaN   NaN NaN
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job with these charts.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# ## 3.8 Genre Analysis
#
# Examining the distribution of games by genre:

# %%
# Analyze genre performance & sort genres by total sales

total_sales_by_genre = platforms_sales_2012_fwd.groupby('genre')['total_sales'].sum().sort_values(ascending=False).to_frame()
total_sales_by_genre.columns = ['total_sales']
print(total_sales_by_genre.head(10))
# Out:
#               total_sales
# genre
# Action             441.12
# Shooter            304.73
# Role-Playing       192.80
# Sports             181.07
# Misc                85.04
# Platform            61.00
# Racing              53.50
# Fighting            44.49
# Simulation          35.12
# Adventure           29.43

# %%
# Visualize genre distribution

total_sales_by_genre.plot(
    kind='bar', 
    title='Genre Total Sales', 
    xlabel='Genre', 
    ylabel='Total Sales (in millions of $)', 
    color='green',
    legend=False,
)

plt.show()
print()

# %%
# Calculate market share for each genre

market_share = total_sales_by_genre['total_sales'].sum()
genre_sales = total_sales_by_genre['total_sales']
total_sales_by_genre['market share %'] = ((genre_sales / market_share) * 100).round(2)
print(total_sales_by_genre)
print()

platforms_sales_2012_fwd = df_games[(df_games['year_of_release'] >= 2012) & (df_games['total_sales'] > 0)]

platforms_sales_by_genre = platforms_sales_2012_fwd.pivot_table(
    index='genre',
    columns=['year_of_release'],
    values=['total_sales'],
    aggfunc='sum'
)
print('Average 2012 - 2016 Sales by Genre:\n', platforms_sales_by_genre.mean())
print()
print('Sales by genre 2012 - 2016:\n', platforms_sales_by_genre)
print()
platforms_sales_by_genre.plot(
    kind='bar', 
    title='Game Sales by Genre (in millions of $)', 
    xlabel='Genre', 
    ylabel='Sales (in millions of $)',
    figsize=(12, 6)
)
plt.show()
print()
# Out:
#               total_sales  market share %
# genre
# Action             441.12           30.50
# Shooter            304.73           21.07
# Role-Playing       192.80           13.33
# Sports             181.07           12.52
# Misc                85.04            5.88
# Platform            61.00            4.22
# Racing              53.50            3.70
# Fighting            44.49            3.08
# Simulation          35.12            2.43
# Adventure           29.43            2.03
# Strategy            13.34            0.92
# Puzzle               4.89            0.34
#
# Average 2012 - 2016 Sales by Genre:
#               year_of_release
# total_sales  2012               29.653333
#              2013               30.103333
#              2014               27.627500
#              2015               22.331667
#              2016               10.828333
# dtype: float64
#
# Sales by genre 2012 - 2016:
#                  total_sales
# ...

# %% [markdown]
# ### Key Questions for Genre Analysis:
# - Which genres consistently perform well?
#     * The Action genre is the clear top performer, Sports a strong second performer, while Shooter, Role-Playing, Platform, Misc and Racing all perform consistently, as well.
# - Are there any genres showing recent growth or decline?
#     * All genres show a decline in total sales from 2015 - 2016. This corresponds with overall decreasing yearly sales by platform
# - How does the average performance vary across genres?
#     * The range of average yearly sales is between $978K and $88 million. The median is $19.5 million.

# %%
print('Average Yearly 2012-2016 Sales by Genre:\n', platforms_sales_by_genre.mean(axis=1).sort_values(ascending=False))
# Out:
# Average Yearly 2012-2016 Sales by Genre:
#  genre
# Action          88.224
# Shooter         60.946
# Role-Playing    38.560
# Sports          36.214
# Misc            17.008
# Platform        12.200
# Racing          10.700
# Fighting         8.898
# Simulation       7.024
# Adventure        5.886
# Strategy         2.668
# Puzzle           0.978
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job with the with this.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %% [markdown]
# # Step 4: Regional Market Analysis and User Profiles
# In this section, we will analyze the gaming market characteristics across three major regions: North America (NA), Europe (EU), and Japan (JP). Our analysis will focus on platform preferences, genre popularity, and the impact of ESRB ratings in each region.

# %% [markdown]
# ## 4.1 Regional Platform Analysis
#
# We'll begin by examining platform performance across different regions:

# %%
# Function to analyze platform performance by region

def platform_performance(dataframe, groupby, regions=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], operation='sum'):

    results = {}
    for region in regions:
        if operation == 'sum':
            results[region] = dataframe.groupby(groupby)[region].sum().reset_index()
        elif operation == 'mean':
            results[region] = dataframe.groupby(groupby)[region].mean().reset_index()
    return results

# %%
# Analyze each region
na_sales_platform_performance_avg = platform_performance(platforms_sales_2012_fwd, 'platform', ['na_sales'], 'mean')
na_sales_platform_performance_sum = platform_performance(platforms_sales_2012_fwd, 'platform', ['na_sales'], 'sum')
print('North America Average Sales by Platform:\n', na_sales_platform_performance_avg)
print()
print('North America Total Sales by Platform:\n', na_sales_platform_performance_sum)
print()


eu_sales_platform_performance_avg = platform_performance(platforms_sales_2012_fwd, 'platform', ['eu_sales'], 'mean')
eu_sales_platform_performance_sum = platform_performance(platforms_sales_2012_fwd, 'platform', ['eu_sales'], 'sum')
print('Europe Average Sales by Platform:\n', eu_sales_platform_performance_avg)
print()
print('Europe Total Sales by Platform:\n', eu_sales_platform_performance_sum)
print()

jp_sales_platform_performance_avg = platform_performance(platforms_sales_2012_fwd, 'platform', ['jp_sales'], 'mean')
jp_sales_platform_performance_sum = platform_performance(platforms_sales_2012_fwd, 'platform', ['jp_sales'], 'sum')
print('Japan Average Sales by Platform:\n', jp_sales_platform_performance_avg)
print()
print('Japan Total Sales by Platform:\n', jp_sales_platform_performance_sum)
print()

other_sales_platform_performance_avg = platform_performance(platforms_sales_2012_fwd, 'platform', ['other_sales'], 'mean')
other_sales_platform_performance_sum = platform_performance(platforms_sales_2012_fwd, 'platform', ['other_sales'], 'sum')
print('Other Regions Average Sales by Platform:\n', other_sales_platform_performance_avg)
print()
print('Other Regions Total Sales by Platform:\n', other_sales_platform_performance_sum)
print()
# Out:
# North America Average Sales by Platform:
#  {'na_sales':    platform  na_sales
# 0       3DS  0.139672
# 1        DS  0.148065
# 2        PC  0.076480
# 3       PS3  0.209696
# 4       PS4  0.277398
# 5       PSP  0.000751
# 6       PSV  0.026715
# 7       Wii  0.323148
# 8      WiiU  0.259184
# 9      X360  0.479623
# 10     XOne  0.377004}
#
# North America Total Sales by Platform:
#  {'na_sales':    platform  na_sales
# 0       3DS     55.31
# 1        DS      4.59
# 2        PC     19.12
# 3       PS3    103.38
# 4       PS4    108.74
# 5       PSP      0.13
# 6       PSV     10.98
# 7       Wii     17.45
# 8      WiiU     38.10
# 9      X360    140.05
# 10     XOne     93.12}
#
# Europe Average Sales by Platform:
#  {'eu_sales':    platform  eu_sales
# 0       3DS  0.107677
# 1        DS  0.113871
# 2        PC  0.151040
# 3       PS3  0.216755
# 4       PS4  0.359923
# 5       PSP  0.002428
# 6       PSV  0.027640
# 7       Wii  0.220741
# 8      WiiU  0.170952
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %% [markdown]
# ### Cross-Regional Platform Comparison
#
# Next we'll create a comparative analysis of platform performance across regions:

# %%
print(type(na_sales_platform_performance_sum))
# Out:
# <class 'dict'>

# %%
# Create a comparative platform analysis


# Combine dictionary objects into one dataframe
na_sum_series = na_sales_platform_performance_sum['na_sales'].set_index('platform')
eu_sum_series = eu_sales_platform_performance_sum['eu_sales'].set_index('platform')
jp_sum_series = jp_sales_platform_performance_sum['jp_sales'].set_index('platform')
other_sum_series = other_sales_platform_performance_sum['other_sales'].set_index('platform')

na_avg_series = na_sales_platform_performance_avg['na_sales'].set_index('platform')
eu_avg_series = eu_sales_platform_performance_avg['eu_sales'].set_index('platform')
jp_avg_series = jp_sales_platform_performance_avg['jp_sales'].set_index('platform')
other_avg_series = other_sales_platform_performance_avg['other_sales'].set_index('platform')

across_region_sum = pd.concat([
    na_sum_series['na_sales'], 
    eu_sum_series['eu_sales'],
    jp_sum_series['jp_sales'],
    other_sum_series['other_sales']], axis=1)
print('Total Sales Across Regions:\n\n', across_region_sum.head(30))
print()

across_region_avg = pd.concat([
    na_avg_series['na_sales'], 
    eu_avg_series['eu_sales'],
    jp_avg_series['jp_sales'],
    other_avg_series['other_sales']], axis=1)
print('Avg Sales Across Regions:\n\n', across_region_avg.head(30))


across_region_sum.plot(
    kind='bar', 
    title='Regional Game Sales (in millions of $)', 
    xlabel='Game', 
    ylabel='Sales (in millions of $)',
    figsize=(12, 6)
)
plt.show()
print()
# Out:
# Total Sales Across Regions:
#
#            na_sales  eu_sales  jp_sales  other_sales
# platform
# 3DS          55.31     42.64     87.79         8.87
# DS            4.59      3.53      3.72         0.71
# PC           19.12     37.76      0.00         5.77
# PS3         103.38    106.86     35.29        43.26
# PS4         108.74    141.09     15.96        48.35
# PSP           0.13      0.42     10.47         0.17
# PSV          10.98     11.36     21.04         5.80
# Wii          17.45     11.92      3.39         2.61
# WiiU         38.10     25.13     13.01         5.95
# X360        140.05     74.52      1.57        20.40
# XOne         93.12     51.59      0.34        14.27
#
# Avg Sales Across Regions:
#
#            na_sales  eu_sales  jp_sales  other_sales
# platform
# 3DS       0.139672  0.107677  0.221692     0.022399
# DS        0.148065  0.113871  0.120000     0.022903
# PC        0.076480  0.151040  0.000000     0.023080
# ...

# %%
across_region_sum['total_sales'] = across_region_sum['eu_sales'] + across_region_sum['na_sales'] + across_region_sum['jp_sales'] + across_region_sum['other_sales']
across_region_sum = across_region_sum.sort_values(by='total_sales', ascending=False)
print(across_region_sum)
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS4         108.74    141.09     15.96        48.35       314.14
# PS3         103.38    106.86     35.29        43.26       288.79
# X360        140.05     74.52      1.57        20.40       236.54
# 3DS          55.31     42.64     87.79         8.87       194.61
# XOne         93.12     51.59      0.34        14.27       159.32
# WiiU         38.10     25.13     13.01         5.95        82.19
# PC           19.12     37.76      0.00         5.77        62.65
# PSV          10.98     11.36     21.04         5.80        49.18
# Wii          17.45     11.92      3.39         2.61        35.37
# DS            4.59      3.53      3.72         0.71        12.55
# PSP           0.13      0.42     10.47         0.17        11.19

# %%
# Visualize cross-regional comparison for top platforms

top_6_regional_platforms_sales = across_region_sum[across_region_sum.index.isin(['PS2', 'PS3', 'DS', 'PS', 'Wii', 'X360'])]
print(top_6_regional_platforms_sales)

top_6_regional_platforms_sales.plot(kind='bar', title='Top 6 Platform Sales Across Regions', ylabel='Sales (in millions of $)', xlabel='Game')
plt.show()
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# PS3         103.38    106.86     35.29        43.26       288.79
# X360        140.05     74.52      1.57        20.40       236.54
# Wii          17.45     11.92      3.39         2.61        35.37
# DS            4.59      3.53      3.72         0.71        12.55

# %% [markdown]
# ## 4.2 Regional Genre Analysis
#
# Next we'll examine genre preferences across regions:

# %%
# Function to analyze genre performance by region

def genre_performance(dataframe, groupby, regions=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'], operation='sum'):

    results = {}
    for region in regions:
        if operation == 'sum':
            results[region] = dataframe.groupby(groupby)[region].sum().reset_index()
        elif operation == 'mean':
            results[region] = dataframe.groupby(groupby)[region].mean().reset_index()
    return results

# %% [markdown]
# ### Cross-Regional Genre Comparison
#
# Next, we'll compare genre preferences across regions:

# %%
# Create a comparative genre analysis

na_sales_genre_performance_avg = genre_performance(platforms_sales_2012_fwd, 'genre', ['na_sales'], 'mean')
na_sales_genre_performance_sum = genre_performance(platforms_sales_2012_fwd, 'genre', ['na_sales'], 'sum')
print('North America Average Sales by Genre:\n', na_sales_genre_performance_avg)
print()
print('North America Total Sales by Genre:\n', na_sales_genre_performance_sum)
print()

eu_sales_genre_performance_avg = genre_performance(platforms_sales_2012_fwd, 'genre', ['eu_sales'], 'mean')
eu_sales_genre_performance_sum = genre_performance(platforms_sales_2012_fwd, 'genre', ['eu_sales'], 'sum')
print('Europe Average Sales by Genre:\n', eu_sales_genre_performance_avg)
print()
print('Europe Total Sales by Genre:\n', eu_sales_genre_performance_sum)
print()

jp_sales_genre_performance_avg = genre_performance(platforms_sales_2012_fwd, 'genre', ['jp_sales'], 'mean')
jp_sales_genre_performance_sum = genre_performance(platforms_sales_2012_fwd, 'genre', ['jp_sales'], 'sum')
print('Japan Average Sales by Genre:\n', jp_sales_genre_performance_avg)
print()
print('Japan Total Sales by Genre:\n', jp_sales_genre_performance_sum)
print()

other_sales_genre_performance_avg = genre_performance(platforms_sales_2012_fwd, 'genre', ['other_sales'], 'mean')
other_sales_genre_performance_sum = genre_performance(platforms_sales_2012_fwd, 'genre', ['other_sales'], 'sum')
print('Other Regions Average Sales by Genre:\n', other_sales_genre_performance_avg)
print()
print('Other Regions Total Sales by Genre:\n', other_sales_genre_performance_sum)
print()
# Out:
# North America Average Sales by Genre:
#  {'na_sales':            genre  na_sales
# 0         Action  0.172493
# 1      Adventure  0.029536
# 2       Fighting  0.181560
# 3           Misc  0.198906
# 4       Platform  0.298588
# 5         Puzzle  0.040357
# 6         Racing  0.149739
# 7   Role-Playing  0.172973
# 8        Shooter  0.616043
# 9     Simulation  0.099625
# 10        Sports  0.304216
# 11      Strategy  0.059577}
#
# North America Total Sales by Genre:
#  {'na_sales':            genre  na_sales
# 0         Action    177.84
# 1      Adventure      8.92
# 2       Fighting     19.79
# 3           Misc     38.19
# 4       Platform     25.38
# 5         Puzzle      1.13
# 6         Racing     17.22
# 7   Role-Playing     64.00
# 8        Shooter    144.77
# 9     Simulation      7.97
# 10        Sports     81.53
# 11      Strategy      4.23}
#
# Europe Average Sales by Genre:
#  {'eu_sales':            genre  eu_sales
# 0         Action  0.154549
# 1      Adventure  0.031325
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %%
# Create a comparative platform analysis

# Combine dictionary objects into one dataframe
na_genre_sum_series = na_sales_genre_performance_sum['na_sales'].set_index('genre')
eu_genre_sum_series = eu_sales_genre_performance_sum['eu_sales'].set_index('genre')
jp_genre_sum_series = jp_sales_genre_performance_sum['jp_sales'].set_index('genre')
other_genre_sum_series = other_sales_genre_performance_sum['other_sales'].set_index('genre')

na_genre_avg_series = na_sales_genre_performance_avg['na_sales'].set_index('genre')
eu_genre_avg_series = eu_sales_genre_performance_avg['eu_sales'].set_index('genre')
jp_genre_avg_series = jp_sales_genre_performance_avg['jp_sales'].set_index('genre')
other_genre_avg_series = other_sales_genre_performance_avg['other_sales'].set_index('genre')

across_region_genre_sum = pd.concat([
    na_genre_sum_series['na_sales'], 
    eu_genre_sum_series['eu_sales'],
    jp_genre_sum_series['jp_sales'],
    other_genre_sum_series['other_sales']], axis=1)

across_region_genre_sum['total_sales'] = na_genre_sum_series['na_sales'] + eu_genre_sum_series['eu_sales'] + jp_genre_sum_series['jp_sales'] + other_genre_sum_series['other_sales']

print('Total Sales Across Regions by Genre:\n\n', across_region_genre_sum.head(30))
print()

across_region_genre_avg = pd.concat([
    na_genre_avg_series['na_sales'], 
    eu_genre_avg_series['eu_sales'],
    jp_genre_avg_series['jp_sales'],
    other_genre_avg_series['other_sales']], axis=1)

across_region_genre_avg['total_sales'] = na_genre_avg_series['na_sales'] + eu_genre_avg_series['eu_sales'] + jp_genre_avg_series['jp_sales'] + other_genre_avg_series['other_sales']

print('Avg Sales Across Regions by Genre:\n\n', across_region_genre_avg.head(30))


across_region_genre_sum.plot(
    kind='bar', 
    title='Regional Game Sales by Genre (in millions of $)', 
    xlabel='Genre', 
    ylabel='Sales (in millions of $)',
    figsize=(12, 6)
)
plt.show()
print()
# Out:
# Total Sales Across Regions by Genre:
#
#                na_sales  eu_sales  jp_sales  other_sales  total_sales
# genre
# Action          177.84    159.34     52.80        51.14       441.12
# Adventure         8.92      9.46      8.24         2.81        29.43
# Fighting         19.79     10.79      9.44         4.47        44.49
# Misc             38.19     26.32     12.86         7.67        85.04
# Platform         25.38     21.41      8.63         5.58        61.00
# Puzzle            1.13      1.40      2.14         0.22         4.89
# Racing           17.22     27.29      2.50         6.49        53.50
# Role-Playing     64.00     48.53     65.44        14.83       192.80
# Shooter         144.77    113.47      9.23        37.26       304.73
# Simulation        7.97     14.55     10.41         2.19        35.12
# Sports           81.53     69.09      8.01        22.44       181.07
# Strategy          4.23      5.17      2.88         1.06        13.34
#
# ...

# %% [markdown]
# ## 4.3 ESRB Rating Impact Analysis
#
# Finally, we'll examine how ESRB ratings affect sales in each region:

# %%
# Function to analyze ESRB rating impact

def rating_performance(dataframe, groupby, regions=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'], operation='sum'):

    results = {}
    for region in regions:
        if operation == 'sum':
            results[region] = dataframe.groupby(groupby)[region].sum().reset_index()
        elif operation == 'mean':
            results[region] = dataframe.groupby(groupby)[region].mean().reset_index()
    return results

# %%
# Analyze ESRB impact for each region

# Create a comparative genre analysis

na_sales_rating_performance_avg = rating_performance(platforms_sales_2012_fwd, 'rating', ['na_sales'], 'mean')
na_sales_rating_performance_sum = rating_performance(platforms_sales_2012_fwd, 'rating', ['na_sales'], 'sum')
print('North America Average Sales by Genre:\n', na_sales_rating_performance_avg)
print()
print('North America Total Sales by Genre:\n', na_sales_rating_performance_sum)
print()

eu_sales_rating_performance_avg = rating_performance(platforms_sales_2012_fwd, 'rating', ['eu_sales'], 'mean')
eu_sales_rating_performance_sum = rating_performance(platforms_sales_2012_fwd, 'rating', ['eu_sales'], 'sum')
print('Europe Average Sales by Genre:\n', eu_sales_genre_performance_avg)
print()
print('Europe Total Sales by Genre:\n', eu_sales_rating_performance_sum)
print()

jp_sales_rating_performance_avg = rating_performance(platforms_sales_2012_fwd, 'rating', ['jp_sales'], 'mean')
jp_sales_rating_performance_sum = rating_performance(platforms_sales_2012_fwd, 'rating', ['jp_sales'], 'sum')
print('Japan Average Sales by Genre:\n', jp_sales_rating_performance_avg)
print()
print('Japan Total Sales by Genre:\n', jp_sales_rating_performance_sum)
print()

other_sales_rating_performance_avg = rating_performance(platforms_sales_2012_fwd, 'rating', ['other_sales'], 'mean')
other_sales_rating_performance_sum = rating_performance(platforms_sales_2012_fwd, 'rating', ['other_sales'], 'sum')
print('Other Regions Average Sales by Rating:\n', other_sales_rating_performance_avg)
print()
print('Other Regions Total Sales by Rating:\n', other_sales_rating_performance_sum)
print()
# Out:
# North America Average Sales by Genre:
#  {'na_sales':   rating  na_sales
# 0      E  0.289544
# 1   E10+  0.247386
# 2      M  0.465000
# 3      T  0.160243}
#
# North America Total Sales by Genre:
#  {'na_sales':   rating  na_sales
# 0      E    114.37
# 1   E10+     75.70
# 2      M    231.57
# 3      T     66.02}
#
# Europe Average Sales by Genre:
#  {'eu_sales':            genre  eu_sales
# 0         Action  0.154549
# 1      Adventure  0.031325
# 2       Fighting  0.098991
# 3           Misc  0.137083
# 4       Platform  0.251882
# 5         Puzzle  0.050000
# 6         Racing  0.237304
# 7   Role-Playing  0.131162
# 8        Shooter  0.482851
# 9     Simulation  0.181875
# 10        Sports  0.257799
# 11      Strategy  0.072817}
#
# Europe Total Sales by Genre:
#  {'eu_sales':   rating  eu_sales
# 0      E    113.03
# 1   E10+     55.37
# 2      M    193.96
# 3      T     52.96}
#
# Japan Average Sales by Genre:
#  {'jp_sales':   rating  jp_sales
# 0      E  0.071722
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %%
# Create a comparative platform analysis


# Combine dictionary objects into one dataframe
na_rating_sum_series = na_sales_rating_performance_sum['na_sales'].set_index('rating')
eu_rating_sum_series = eu_sales_rating_performance_sum['eu_sales'].set_index('rating')
jp_rating_sum_series = jp_sales_rating_performance_sum['jp_sales'].set_index('rating')
other_rating_sum_series = other_sales_rating_performance_sum['other_sales'].set_index('rating')

na_rating_avg_series = na_sales_rating_performance_avg['na_sales'].set_index('rating')
eu_rating_avg_series = eu_sales_rating_performance_avg['eu_sales'].set_index('rating')
jp_rating_avg_series = jp_sales_rating_performance_avg['jp_sales'].set_index('rating')
other_rating_avg_series = other_sales_rating_performance_avg['other_sales'].set_index('rating')

across_region_rating_sum = pd.concat([
    na_rating_sum_series['na_sales'], 
    eu_rating_sum_series['eu_sales'],
    jp_rating_sum_series['jp_sales'],
    other_rating_sum_series['other_sales']], axis=1)

across_region_rating_sum['total_sales'] = na_rating_sum_series['na_sales'] + eu_rating_sum_series['eu_sales'] + jp_rating_sum_series['jp_sales'] + other_rating_sum_series['other_sales']

print('Total Sales Across Regions by Rating:\n\n', across_region_rating_sum.head(30))
print()

across_region_rating_avg = pd.concat([
    na_rating_avg_series['na_sales'], 
    eu_rating_avg_series['eu_sales'],
    jp_rating_avg_series['jp_sales'],
    other_rating_avg_series['other_sales']], axis=1)

across_region_rating_avg['total_sales'] = na_rating_avg_series['na_sales'] + eu_rating_avg_series['eu_sales'] + jp_rating_avg_series['jp_sales'] + other_rating_avg_series['other_sales']

print('Avg Sales Across Regions by Rating:\n\n', across_region_rating_avg.head(30))


across_region_rating_sum.plot(
    kind='bar', 
    title='Regional Game Sales by Rating (in millions of $)', 
    xlabel='Rating', 
    ylabel='Sales (in millions of $)',
    figsize=(12, 6)
)
plt.show()
print()
# Out:
# Total Sales Across Regions by Rating:
#
#          na_sales  eu_sales  jp_sales  other_sales  total_sales
# rating
# E         114.37    113.03     28.33        31.44       287.17
# E10+       75.70     55.37      8.19        16.23       155.49
# M         231.57    193.96     21.20        63.38       510.11
# T          66.02     52.96     26.02        17.94       162.94
#
# Avg Sales Across Regions by Rating:
#
#          na_sales  eu_sales  jp_sales  other_sales  total_sales
# rating
# E       0.289544  0.286152  0.071722     0.079595     0.727013
# E10+    0.247386  0.180948  0.026765     0.053039     0.508137
# M       0.465000  0.389478  0.042570     0.127269     1.024317
# T       0.160243  0.128544  0.063155     0.043544     0.395485

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job so far with the regional analysis.
#
# </div>

# %% [markdown]
# # Step 5 : Hypothesis Tests

# %% [markdown]
# ### Formulating null & alternative hypothesis
#
# Null Hypothesis A:
# Average user ratings of the Xbox One and PC platforms are the same.
#
# Alternative Hypothesis A:
# Average user ratings of the Xbox One and PC platforms are not the same.

# %% [markdown]
# ### Choosing significance threshold (alpha)
# alpha=0.05

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %% [markdown]
# ### Choosing the statistical test
# Since we don't care what side of the curve the result falls on, we'd use a two-tailed hypothesis & t-test.

# %%
# Create comparison dataframes for t-test
df_xone = platforms_sales_2012_fwd[platforms_sales_2012_fwd['platform'] == 'XOne']['user_score'].dropna()
df_pc = platforms_sales_2012_fwd[platforms_sales_2012_fwd['platform'] == 'PC']['user_score'].dropna()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good work updating the dataframe.
#
# </div>

# %%
print('XOne User Scores:\n', df_xone.head(5))
print()
print('PC User Scores:\n', df_pc.head(5))
print()
print('XOne Stats:\n', df_xone.describe())
print()
print('PC Stats:\n', df_pc.describe())
# Out:
# XOne User Scores:
#  165    7.9
# 179    5.4
# 242    6.4
# 270    6.2
# 373    4.1
# Name: user_score, dtype: float64
#
# PC User Scores:
#  192     4.0
# 458     3.9
# 688     7.9
# 959     4.8
# 1095    7.9
# Name: user_score, dtype: float64
#
# XOne Stats:
#  count    182.000000
# mean       6.521429
# std        1.380941
# min        1.600000
# 25%        5.800000
# 50%        6.800000
# 75%        7.500000
# max        9.200000
# Name: user_score, dtype: float64
#
# PC Stats:
#  count    206.000000
# mean       6.428641
# std        1.664465
# min        1.400000
# 25%        5.500000
# 50%        6.800000
# 75%        7.700000
# max        9.300000
# Name: user_score, dtype: float64

# %%
print('XOne Variance:\n', np.var(df_xone))
print()
print('PC Variance:\n', np.var(df_pc))
print()
print('XOne standard deviation:\n', np.std(df_xone))
print()
print('PC standard deviation:\n', np.std(df_pc))
# Out:
# XOne Variance:
#  1.8965188383045526
#
# PC Variance:
#  2.7569952398906588
#
# XOne standard deviation:
#  1.377141546212499
#
# PC standard deviation:
#  1.660420199796021

# %%
# Calculate variance

xone_var = np.var(df_xone)
pc_var = np.var(df_pc)

variance_ratio = pc_var / xone_var
print('Variance Ratio:', variance_ratio)

if variance_ratio <= 2:
    print('Variance similar enough to use equal_var=True in t-test')
else:
    print('Variance not similar enough, use equal_var=False for t-test')
# Out:
# Variance Ratio: 1.4537136063227054
# Variance similar enough to use equal_var=True in t-test

# %%
# t-test
st.ttest_ind(df_xone, df_pc, equal_var=True)
# Out:
# Ttest_indResult(statistic=0.5930304646661255, pvalue=0.5535080500643661)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good result.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job with the null and alternative hypothesis, and also answering the questions.
#
# </div>

# %% [markdown]
# ***Decision:***
#
# Because the pvalue is higher than our alpha treshold, we fail to reject Null Hypothesis A

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %% [markdown]
# ### Choosing another Null Hypothesis
#
# Null Hypothesis B:
# Average user ratings for the Action and Sports genres are different.
#
# Alternative Hypothesis B:
# Average user ratings for the Action and Sports genres are not different.

# %% [markdown]
# ### Choosing significance threshold (alpha)
# alpha=0.05

# %% [markdown]
# ### Choosing the type of statistical test
# Since we don't care what side of the curve the result falls on, we'd use a two-tailed hypothesis & t-test.

# %%
# Create comparison dataframes for t-test
df_action = platforms_sales_2012_fwd[platforms_sales_2012_fwd['genre'] == 'Action']['user_score'].dropna()
df_sports = platforms_sales_2012_fwd[platforms_sales_2012_fwd['genre'] == 'Sports']['user_score'].dropna()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good work updating the dataframe.
#
# </div>

# %%
print('Action genre User Scores:\n', df_action.head(5))
print()
print('Sports genre User Scores:\n', df_sports.head(5))
print()
print('Action Stats:\n', df_action.describe())
print()
print('Sports Stats:\n', df_sports.describe())
# Out:
# Action genre User Scores:
#  16     8.2
# 23     8.1
# 42     8.3
# 81     6.6
# 127    6.9
# Name: user_score, dtype: float64
#
# Sports genre User Scores:
#  77     4.3
# 94     5.0
# 126    4.3
# 143    5.7
# 264    4.5
# Name: user_score, dtype: float64
#
# Action Stats:
#  count    523.000000
# mean       6.825048
# std        1.374440
# min        1.600000
# 25%        6.250000
# 50%        7.100000
# 75%        7.800000
# max        9.100000
# Name: user_score, dtype: float64
#
# Sports Stats:
#  count    195.000000
# mean       5.455897
# std        1.738646
# min        0.200000
# 25%        4.300000
# 50%        5.700000
# 75%        6.800000
# max        8.800000
# Name: user_score, dtype: float64

# %%
# Calculate variance

action_var = np.var(df_action)
sports_var = np.var(df_sports)
print('Action genre/User Score variance:', action_var)
print('Sports genre/User Score variance:', sports_var)

genre_variance_ratio = sports_var / action_var
print('Genre/User Score Variance Ratio:', genre_variance_ratio)

if variance_ratio <= 2:
    print('Genre/User Score Variance similar enough to use equal_var=True in t-test')
else:
    print('Genre/User Score Variance not similar enough, use equal_var=False for t-test')
# Out:
# Action genre/User Score variance: 1.8854720340439224
# Sports genre/User Score variance: 3.0073882971729127
# Genre/User Score Variance Ratio: 1.5950320359420695
# Genre/User Score Variance similar enough to use equal_var=True in t-test

# %%
# t-test
st.ttest_ind(df_action, df_sports, equal_var=True)
# Out:
# Ttest_indResult(statistic=11.010635282641651, pvalue=3.7163089460934874e-26)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 3</b> <a class="tocSkip"></a>
#
# Good result.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good job with the null and alternative hypothesis, and also answering the questions.
#
# </div>

# %% [markdown]
# ***Decision:***
#
# Because the pvalue is lower than our alpha threshold, we reject Null Hypothesis B.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Done!</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 4</b> <a class="tocSkip"></a>
#
# Good job with the update.
#
# </div>

# %% [markdown]
# # Step 6. Write a general conclusion

# %% [markdown]
# ### General Conclusions:
#
# Overall, the platforms in out dataset have experienced declines in sales going into 2016.
#
# ***User & Critic Scores:***
#
# User & Critic Scores' missing values closely mirror each other year to year, in some years they are equal. They both increase in 1994, decrease from 1994 - 2004, dramatically increase from 2005 - 2009, then experience a sharp drop/decrease in 2012 - 2016. There does not seem to be a clear reason in the dataset to explain why for any of these patterns, other than the increase in both user & critic scores happens in 1994, the same year that the ESRB started rating games.
#
# There is a weak-to-low-moderate correlation between how much Total Sales a game makes and how high the Critic Score is. In summary, Critic Score does not seem to affect sales significantly. However, there is a moderate positive correlation between PS4 all region total sales and Critic Score in our individual platform study of PS4, which suggests that Critic Score does have some effect on game sales.
#
# However, there is a very weak correlation between how much Total Sales a game makes and how high the User Score is. In summary, User Score does not seem to affect sales. We can support this by referencing our individual platform study of PS4, showing that there is negligible negative correlation between PS4 all region total sales and User Score.
#
# A pattern that does not seem to have any answers in the data shows that the Total Sales for games actually begin to fall when Critic score hits about 85 and User score hits about 90.
#
# ***Platforms:***
#
# The PS platforms (PS, PS2, PS3, PS4) are by far the mnost successful platforms overall, holding 4 of the top 6 total overall sales from 1980 - 2016 (the range of our dataset).
#
# ***Genres:***
#
# The Action genre is the clear top performer, Sports a strong second performer, while Shooter, Role-Playing, Platform, Misc and Racing all perform consistently, as well.
#
# All genres show a decline in total sales from 2015 - 2016. This corresponds with overall decreasing yearly sales by platform
#
# ***Regions:***
#
# North America, overall, has the highest total sales, with the European Union coming in 2nd.
#
# ***Ratings:***
#
# While ratings do not seem to have an effect on sales, the E (Everyone) rating garners the highest total sales by far, with M (Mature) and T (Teen) bringing in relatively similar sales. The E10+ (Everyone 10+) has the fourth highest overall sales.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment 2</b> <a class="tocSkip"></a>
#
# Good conclusion.
#
# </div>
